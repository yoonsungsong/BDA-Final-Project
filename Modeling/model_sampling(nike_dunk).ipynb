# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

import warnings
warnings.filterwarnings(action='ignore')

import matplotlib
matplotlib.rc('font', family='AppleGothic')
matplotlib.rc('axes', unicode_minus=False)

from IPython.display import set_matplotlib_formats
set_matplotlib_formats('retina')

pd.options.display.max_rows=100
pd.options.display.max_columns=100
# pd.set_option('display.float_format','{:.4f}'.format)

# %%
data = pd.read_csv('data/nike_dunk(pre).csv')

# %%
data.drop('Unnamed: 0', axis=1, inplace=True)

# %%
print(data.shape)
data.head()
# Out:
# (224192, 13)
#    size   price        date                            product release_date  \
# 0   245  125000  2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 1   240  123000  2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 2   245  129000  2021-10-01  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 3   275  129000  2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 4   240  132000  2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
#
#                      color  release_price brand   category   number  wish  \
# 0  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 1  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 2  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 3  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 4  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
#
#    review  transactions
# 0     4.0            30
# 1     4.0            30
# 2     4.0            30
# 3     4.0            30
# 4     4.0            30

# %%
pd.pivot_table(data, index='product', values='price', aggfunc='mean')
# Out:
#                                                            price
# product
# (GS) Nike Dunk High Anthracite                      1.318333e+05
# (GS) Nike Dunk High Barely Green                    1.568997e+05
# (GS) Nike Dunk High Black and White                 2.205869e+05
# (GS) Nike Dunk High Cargo Khaki                     1.482043e+05
# (GS) Nike Dunk High Championship Navy               1.802532e+05
# ...                                                          ...
# Nike x Travis Scott SB Dunk Low (Special Box)       2.922438e+06
# Nike x Undercover Dunk High 1985 Gym Red            1.917731e+05
# Nike x Verdy Girls Don't Cry SB Dunk Low            2.083333e+06
# Nike x Verdy SB Dunk Low Pro Wasted Youth (Regu...  3.268636e+05
# Nike x Verdy SB Dunk Low Pro Wasted Youth (Spec...  4.013636e+05
#
# [363 rows x 1 columns]

# %%
data.groupby('product')['price'].mean()
# Out:
# product
# (GS) Nike Dunk High Anthracite                             1.318333e+05
# (GS) Nike Dunk High Barely Green                           1.568997e+05
# (GS) Nike Dunk High Black and White                        2.205869e+05
# (GS) Nike Dunk High Cargo Khaki                            1.482043e+05
# (GS) Nike Dunk High Championship Navy                      1.802532e+05
#                                                                ...
# Nike x Travis Scott SB Dunk Low (Special Box)              2.922438e+06
# Nike x Undercover Dunk High 1985 Gym Red                   1.917731e+05
# Nike x Verdy Girls Don't Cry SB Dunk Low                   2.083333e+06
# Nike x Verdy SB Dunk Low Pro Wasted Youth (Regular Box)    3.268636e+05
# Nike x Verdy SB Dunk Low Pro Wasted Youth (Special Box)    4.013636e+05
# Name: price, Length: 363, dtype: float64

# %% [markdown]
# ## EDA

# %%
df = data.copy()

# %% [markdown]
# ### Missing Value

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 224192 entries, 0 to 224191
# Data columns (total 13 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   size           224192 non-null  int64
#  1   price          224192 non-null  int64
#  2   date           224192 non-null  object
#  3   product        224192 non-null  object
#  4   release_date   224192 non-null  object
#  5   color          224192 non-null  object
#  6   release_price  224192 non-null  int64
#  7   brand          214342 non-null  object
#  8   category       214342 non-null  object
#  9   number         214342 non-null  float64
#  10  wish           214342 non-null  float64
#  11  review         214342 non-null  float64
#  12  transactions   224192 non-null  int64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 22.2+ MB

# %%
df = df[df['number'].notnull()]

# %%
df = df.reset_index(drop=True)

# %%
print(df.shape)
df.head()
# Out:
# (214342, 13)
#    size   price        date                            product release_date  \
# 0   245  125000  2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 1   240  123000  2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 2   245  129000  2021-10-01  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 3   275  129000  2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 4   240  132000  2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
#
#                      color  release_price brand   category   number  wish  \
# 0  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 1  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 2  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 3  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 4  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
#
#    review  transactions
# 0     4.0            30
# 1     4.0            30
# 2     4.0            30
# 3     4.0            30
# 4     4.0            30

# %%
len(set(df['product']))
# Out:
# 265

# %% [markdown]
# ### type 생성

# %%
df['product'].value_counts()
# Out:
# Nike Dunk Low Retro Black                  18150
# Nike Dunk Low SE Seoul                      7758
# (W) Nike Dunk Low Black                     6700
# Nike Dunk Low Retro University Blue         4450
# Nike x Ambush Dunk High Deep Royal Blue     4450
#                                            ...
# (W) Nike Dunk High University Gold             1
# Nike Dunk SB High Concept Car                  1
# Nike Dunk High Kentucky                        1
# (GS) Nike Dunk High Knicks                     1
# Nike Dunk SB High Black Purple Box             1
# Name: product, Length: 265, dtype: int64

# %%
df.loc[df['product'].str.contains(' Low', regex=False), 'type'] = 'Low'
df.loc[df['product'].str.contains(' High', regex=False), 'type'] = 'High'

# %%
df['type'].value_counts()
# Out:
# Low     164081
# High     50210
# Name: type, dtype: int64

# %%
df[df['type'].isnull()]['product'].value_counts()
# Out:
# (PS) Nike Dunk low Retro Hyper Cobalt    28
# (TD) Nike Dunk low Retro Hyper Cobalt    23
# Name: product, dtype: int64

# %%
df.loc[df['product'].str.contains(' Low', regex=False) == False, 'product'].value_counts()
# Out:
# Nike x Ambush Dunk High Deep Royal Blue                   4450
# (W) Nike Dunk High Black and White                        2950
# Nike Dunk High SP Varsity Maize                           2900
# Nike Dunk High Retro Championship Navy                    2853
# Nike x Ambush Dunk High Black                             2688
# Nike Dunk High SP Maize & Blue                            2370
# Nike x Ambush Dunk High Flash Lime                        2364
# Nike Dunk High Retro Vast Grey                            1752
# Nike Dunk High Retro Black and White                      1581
# Nike x Fragment Dunk High Black                           1450
# Nike Dunk High SP Spartan Green                           1450
# Nike Dunk High SP Pure Platinum                           1450
# Nike x Undercover Dunk High 1985 Gym Red                  1450
# Nike Dunk High Retro Game Royal                           1450
# (GS) Nike Dunk High Orange Blaze                          1450
# Nike Dunk High Barely Green                               1450
# (W) Nike Dunk High Up Black and White                     1409
# (W) Nike Dunk High Orange Blaze                           1273
# (W) Nike Dunk High Football Grey                          1259
# (W) Nike Dunk High Aluminum                               1073
# (GS) Nike Dunk High Championship Navy                     1031
# (W) Nike Dunk High SP Varsity Purple                      1014
# (W) Nike Dunk High Team Red                                994
# (GS) Nike Dunk High Barely Green                           758
# (GS) Nike Dunk High Black and White                        719
# (W) Nike Dunk High Dark Sulfur                             596
# Nike Dunk High Premium EMB Court Purple                    595
# Nike Dunk High SE First Use Sail                           504
# (W) Nike Dunk High Crimson Tint                            441
# (GS) Nike Dunk High Game Royal                             411
# Nike SB Dunk High Pro Maize and Black                      384
# Nike Dunk High PRM EMB College Navy                        339
# Nike Dunk High Retro PRM Light Chocolate                   315
# (GS) Nike Dunk High Cargo Khaki                            279
# (W) Nike Dunk High Moon Fossil                             272
# Nike SB Dunk High Pro Test Pattern                         263
# Nike Dunk High 1985 SP Black Acid Wash                     263
# Nike Dunk High Retro Black White                           247
# Nike Dunk High Retro Orange Blaze                          200
# (W) Nike Dunk High SE First Use Sail University Orange     147
# (W) Nike Dunk High Sail Gum                                135
# (W) Nike Dunk High Up Iron Purple                          134
# (PS) Nike Dunk High SP Varsity Maize                       116
# Nike Dunk High SE First Use University Red                 101
# Nike Dunk High 1985 SP Red Acid Wash                        95
# (GS) Nike Dunk High Retro Vast Grey                         79
# (W) Nike Dunk High Up Summit White                          74
# (GS) Nike Dunk High SE First Use Sail                       67
# (PS) Nike Dunk High Black and White                         59
# (PS) Nike Dunk High Retro Vast Grey                         54
# (W) Nike Dunk High Cashmere                                 47
# (W) Nike Dunk High Next Nature Summit White                 41
# (W) Nike Dunk High Up Pink Oxford                           40
# (W) Nike Dunk High Up Varsity Maize                         34
# (PS) Nike Dunk low Retro Hyper Cobalt                       28
# Nike Dunk High Retro SE Camo Black Royal                    26
# (W) Nike Dunk High Up Pastels                               25
# Nike Dunk SB High Premier Northern Lights                   24
# (TD) Nike Dunk low Retro Hyper Cobalt                       23
# (PS) Nike Dunk High SP Pure Platinum                        22
# (W) Nike Dunk High Grey Fog                                 19
# (W) Nike Dunk High Next Nature Pink Oxford                  19
# (W) Nike Dunk High Up Black and Varsity Maize               14
# Nike Dunk SB High Homegrown Ale Brown                       13
# (W) Nike Dunk High SE First Use University Gold             13
# Nike Dunk High CMFT Premium Red October                     13
# Nike Dunk High All-Star Game 2015                            8
# (PS) Nike Dunk High Orange Blaze                             8
# Nike Dunk SB High Premium 510                                7
# Nike Dunk SB High Waffle                                     7
# (GS) Nike Dunk High Anthracite                               6
# Nike Dunk High Premium SP Cocoa                              6
# Nike Dunk High Michigan                                      5
# (PS) Nike Dunk High Championship Navy                        5
# Nike Dunk High Retro QS St. John's                           5
# Nike Dunk High Lux SP Black                                  4
# Nike Dunk High 3M Snake                                      4
# (PS) Nike Dunk High Game Royal                               3
# Nike Dunk SB High Hackey Sack                                3
# Nike Dunk High Syracuse                                      3
# Nike Dunk High UNLV                                          3
# Nike Dunk High Lux SP Gym Red                                3
# Nike Dunk SB High Wolf In Sheep's Clothing                   3
# Nike Dunk SB High Frank Kozik                                2
# Nike Dunk High Retro University Red                          2
# Nike Dunk High Retro Next Nature Rattan Sail                 2
# Nike Dunk High CMFT Premium Light Retro                      2
# Nike Dunk High Premium SB Acapulco Gold                      2
# Nike Dunk SB High Concept Car                                1
# (GS) Nike Dunk High Knicks                                   1
# (W) Nike Dunk High University Gold                           1
# Nike Dunk High N7 2017                                       1
# Nike Dunk High Premium Ultimate Glory                        1
# Nike Dunk High Premium SB Flamingo                           1
# Nike Dunk High Kentucky                                      1
# Nike Dunk High Pro SB Syracuse                               1
# Nike Dunk SB High Black Purple Box                           1
# Name: product, dtype: int64

# %%
df.loc[df['product'].str.contains('Dunk low', regex=False), 'type'] = 'Low'

# %%
df['type'].value_counts()
# Out:
# Low     164132
# High     50210
# Name: type, dtype: int64

# %%
df[['product', 'type']].value_counts().head(50)
# Out:
# product                                              type
# Nike Dunk Low Retro Black                            Low     18150
# Nike Dunk Low SE Seoul                               Low      7758
# (W) Nike Dunk Low Black                              Low      6700
# Nike Dunk Low Retro University Blue                  Low      4450
# Nike x Ambush Dunk High Deep Royal Blue              High     4450
# (W) Nike Dunk Low Light Bone                         Low      4400
# Nike x Kasina Dunk Low 80's Bus                      Low      4345
# (GS) Nike Dunk Low Black                             Low      4100
# Nike Dunk Low Retro Varsity Green                    Low      4050
# Nike x Off-White Dunk Low The 50 - Lot 18            Low      3800
# Nike Dunk Low Retro Medium Grey                      Low      3107
# Nike x Off-White Dunk Low The 50 - Lot 46            Low      3100
# Nike Dunk Low Retro Championship Red                 Low      3000
# (PS) Nike Dunk Low Black                             Low      2985
# (W) Nike Dunk High Black and White                   High     2950
# Nike SB Dunk Low Pro Chicago                         Low      2900
# Nike Dunk High SP Varsity Maize                      High     2900
# Nike Dunk High Retro Championship Navy               High     2853
# (W) Nike Dunk Low Next Nature Pale Coral             Low      2837
# (W) Nike Dunk Low Triple White                       Low      2767
# Nike Dunk Low Retro Varsity Maize                    Low      2750
# Nike x Ambush Dunk High Black                        High     2688
# (W) Nike Dunk Low Next Nature Sail                   Low      2594
# Nike Dunk High SP Maize & Blue                       High     2370
# Nike x Ambush Dunk High Flash Lime                   High     2364
# Nike Dunk Low SP Community Garden                    Low      2161
# Nike Dunk Low Retro Grey Fog                         Low      2072
# Nike Dunk Low Pro Premium Medium Curry               Low      2000
# Nike x Kasina Dunk Low Road Sign - Kasina Exclusive  Low      1900
# Nike Dunk High Retro Vast Grey                       High     1752
# Nike Dunk Low Retro Championship Goldenrod           Low      1750
# Nike Dunk High Retro Black and White                 High     1581
# (W) Nike Dunk Low Pearl White                        Low      1550
# (W) Nike Dunk Low Coast                              Low      1550
# (W) Nike Dunk Low Orange Pearl                       Low      1500
# Nike Dunk Low Retro Championship Grey                Low      1467
# Nike Dunk High Barely Green                          High     1450
# Nike x Parra SB Dunk Low Pro Abstract Art            Low      1450
# Nike x Fragment Dunk High Black                      High     1450
# Nike x Undercover Dunk High 1985 Gym Red             High     1450
# Nike Dunk High SP Pure Platinum                      High     1450
# Nike Dunk High Retro Game Royal                      High     1450
# Nike x Travis Scott SB Dunk Low                      Low      1450
# Nike Dunk High SP Spartan Green                      High     1450
# (GS) Nike Dunk Low Varsity Maize                     Low      1450
# (GS) Nike Dunk Low University Blue                   Low      1450
# Nike Dunk Low Retro PRM Halloween                    Low      1450
# Nike Dunk Low SE Black Multi Camo                    Low      1450
# Nike Dunk Low SE Free.99 White                       Low      1450
# Nike Dunk Low SP Ceramic                             Low      1450
# dtype: int64

# %% [markdown]
# ### transactions

# %%
# df = df[df['transactions'] > 50]

# %%
df['transactions'].value_counts()
# Out:
# 1450     23200
# 18150    18150
# 4450      8900
# 7758      7758
# 6700      6700
#          ...
# 5           15
# 2           12
# 12          12
# 1           11
# 9            9
# Name: transactions, Length: 183, dtype: int64

# %%
df[df['transactions'] == 1450]['product'].value_counts()
# Out:
# Nike Dunk High Barely Green                  1450
# Nike Dunk Low SP Samba 2020                  1450
# Nike Dunk High SP Spartan Green              1450
# Nike Dunk High Retro Game Royal              1450
# Nike Dunk High SP Pure Platinum              1450
# (GS) Nike Dunk Low University Blue           1450
# Nike Dunk Low SE Black Multi Camo            1450
# Nike Dunk Low SP Ceramic                     1450
# Nike x Travis Scott SB Dunk Low              1450
# Nike x Undercover Dunk High 1985 Gym Red     1450
# Nike x Fragment Dunk High Black              1450
# Nike x Parra SB Dunk Low Pro Abstract Art    1450
# (GS) Nike Dunk High Orange Blaze             1450
# (GS) Nike Dunk Low Varsity Maize             1450
# Nike Dunk Low SE Free.99 White               1450
# Nike Dunk Low Retro PRM Halloween            1450
# Name: product, dtype: int64

# %%
sns.histplot(df['transactions'])
# Out:
# <AxesSubplot:xlabel='transactions', ylabel='Count'>

# %%
sns.histplot(np.log(df['transactions']))
# Out:
# <AxesSubplot:xlabel='transactions', ylabel='Count'>

# %% [markdown]
# ### review

# %%
sns.histplot(df['review'])
# Out:
# <AxesSubplot:xlabel='review', ylabel='Count'>

# %%
sns.histplot(np.log(df['review'] + 0.000001))
# Out:
# <AxesSubplot:xlabel='review', ylabel='Count'>

# %%
df['review_log'] = np.log(df['review'] + 0.000001)

# %%
sns.jointplot( df['price'], df['review'])
plt.show()

# %%
sns.jointplot( df['price'], df['review_log'])
plt.show()

# %%
df[['review_log', 'review']]
# Out:
#         review_log  review
# 0         1.386295     4.0
# 1         1.386295     4.0
# 2         1.386295     4.0
# 3         1.386295     4.0
# 4         1.386295     4.0
# ...            ...     ...
# 214337    5.590987   268.0
# 214338    5.590987   268.0
# 214339    5.590987   268.0
# 214340    5.590987   268.0
# 214341    5.590987   268.0
#
# [214342 rows x 2 columns]

# %%
df.head(1)
# Out:
#    size   price        date                            product release_date  \
# 0   245  125000  2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
#
#                      color  release_price brand   category   number  wish  \
# 0  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
#
#    review  transactions type  review_log
# 0     4.0            30  Low    1.386295

# %% [markdown]
# ### wish

# %%
sns.histplot(df['wish'])
# Out:
# <AxesSubplot:xlabel='wish', ylabel='Count'>

# %%
sns.histplot(np.log(df['wish'] + 0.000001))
# Out:
# <AxesSubplot:xlabel='wish', ylabel='Count'>

# %%
df['wish_log'] = np.log(df['wish'] + 0.000001)

# %%
df.head(1)
# Out:
#    size   price        date                            product release_date  \
# 0   245  125000  2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
#
#                      color  release_price brand   category   number  wish  \
# 0  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
#
#    review  transactions type  review_log  wish_log
# 0     4.0            30  Low    1.386295    4.5326

# %% [markdown]
# ### date
# - min_date 추가
# - max_date 추가

# %%
# min_max_date = pd.pivot_table(df, index='product', values='date', aggfunc=(min, max))

# %%
# min_max_date = pd.DataFrame({'product': min_max_date.index, 'start_date': min_max_date['min'], 'end_date': min_max_date['max']}).reset_index(drop=True)

# %%
# min_max_date

# %%
# df = pd.merge(df, min_max_date, how='left', on='product')

# %%
# df['start_date']

# %%
# df[(df['start_date'] <= '2021-01') & (df['end_date'] >= '2021-12')]['product'].value_counts()

# %%
# df[df['product'] == 'Nike Dunk Low Triple White']

# %%
# df = df[(df['start_date'] <= '2021-01') & (df['end_date'] >= '2021-12')]

# %%
# df.reset_index(drop=True, inplace=True)

# %% [markdown]
# ### release_price

# %%
df['release_price'].value_counts().sort_index()
# Out:
# 59000      1622
# 59300        10
# 59400        23
# 65000        90
# 69000       712
# 72400         8
# 74000         4
# 77100        28
# 77200        11
# 79000      6027
# 83000        92
# 85000       219
# 85800         3
# 90200        16
# 99000      9779
# 100500       54
# 100800      333
# 101000       40
# 106800       70
# 108200        1
# 109000     5454
# 112700      509
# 115000      196
# 118600     3937
# 118800       30
# 119000    91531
# 120200        1
# 124900        8
# 129000    56743
# 129900        2
# 130500     2148
# 130700        5
# 132300       45
# 137000      135
# 139000     5376
# 142400      417
# 142600       31
# 143300       10
# 144300       86
# 146100       32
# 147400      229
# 147600       79
# 149000      634
# 156300        1
# 159000      418
# 160200       20
# 160900     1875
# 163000        2
# 179000     5181
# 180400        7
# 186000       30
# 186300       30
# 213600      573
# 213900        6
# 219000    19002
# 227200      417
# Name: release_price, dtype: int64

# %%
print(df.shape)
df.head()
# Out:
# (214342, 16)
#    size   price        date                            product release_date  \
# 0   245  125000  2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 1   240  123000  2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 2   245  129000  2021-10-01  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 3   275  129000  2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 4   240  132000  2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
#
#                      color  release_price brand   category   number  wish  \
# 0  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 1  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 2  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 3  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 4  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
#
#    review  transactions type  review_log  wish_log
# 0     4.0            30  Low    1.386295    4.5326
# 1     4.0            30  Low    1.386295    4.5326
# 2     4.0            30  Low    1.386295    4.5326
# 3     4.0            30  Low    1.386295    4.5326
# 4     4.0            30  Low    1.386295    4.5326

# %%
df[100:150]
# Out:
#      size   price        date                                 product  \
# 100   230  236000  2021-12-08  (W) Nike Dunk Low Disrupt Carbon Green
# 101   270  240000  2021-12-09  (W) Nike Dunk Low Disrupt Carbon Green
# 102   270  245000  2021-12-09  (W) Nike Dunk Low Disrupt Carbon Green
# 103   270  259000  2021-12-09  (W) Nike Dunk Low Disrupt Carbon Green
# 104   245  201000  2021-12-09  (W) Nike Dunk Low Disrupt Carbon Green
# 105   285  315000  2021-12-10  (W) Nike Dunk Low Disrupt Carbon Green
# 106   265  230000  2021-12-11  (W) Nike Dunk Low Disrupt Carbon Green
# 107   275  210000  2021-12-11  (W) Nike Dunk Low Disrupt Carbon Green
# 108   260  200000  2021-12-11  (W) Nike Dunk Low Disrupt Carbon Green
# 109   225  220000  2021-12-11  (W) Nike Dunk Low Disrupt Carbon Green
# 110   240  245000  2021-12-12  (W) Nike Dunk Low Disrupt Carbon Green
# 111   275  258000  2021-12-12  (W) Nike Dunk Low Disrupt Carbon Green
# 112   280  200000  2021-12-15  (W) Nike Dunk Low Disrupt Carbon Green
# 113   230  239000  2021-12-15  (W) Nike Dunk Low Disrupt Carbon Green
# 114   245  226000  2021-12-17  (W) Nike Dunk Low Disrupt Carbon Green
# 115   245  226000  2021-12-18  (W) Nike Dunk Low Disrupt Carbon Green
# 116   280  210000  2021-12-19  (W) Nike Dunk Low Disrupt Carbon Green
# 117   275  299000  2021-12-19  (W) Nike Dunk Low Disrupt Carbon Green
# 118   250  219000  2021-12-19  (W) Nike Dunk Low Disrupt Carbon Green
# 119   265  230000  2021-12-21  (W) Nike Dunk Low Disrupt Carbon Green
# 120   245  227000  2021-12-21  (W) Nike Dunk Low Disrupt Carbon Green
# 121   230  248000  2021-12-21  (W) Nike Dunk Low Disrupt Carbon Green
# 122   260  230000  2021-12-21  (W) Nike Dunk Low Disrupt Carbon Green
# 123   255  218000  2021-12-21  (W) Nike Dunk Low Disrupt Carbon Green
# 124   250  220000  2021-12-21  (W) Nike Dunk Low Disrupt Carbon Green
# 125   245  245000  2021-12-22  (W) Nike Dunk Low Disrupt Carbon Green
# 126   265  249000  2021-12-22  (W) Nike Dunk Low Disrupt Carbon Green
# 127   250  240000  2021-12-22  (W) Nike Dunk Low Disrupt Carbon Green
# 128   265  250000  2021-12-22  (W) Nike Dunk Low Disrupt Carbon Green
# 129   230  230000  2021-12-24  (W) Nike Dunk Low Disrupt Carbon Green
# 130   230  235000  2021-12-24  (W) Nike Dunk Low Disrupt Carbon Green
# 131   265  270000  2021-12-25  (W) Nike Dunk Low Disrupt Carbon Green
# 132   280  250000  2021-12-27  (W) Nike Dunk Low Disrupt Carbon Green
# 133   255  218000  2021-12-27  (W) Nike Dunk Low Disrupt Carbon Green
# 134   255  220000  2021-12-27  (W) Nike Dunk Low Disrupt Carbon Green
# 135   270  250000  2021-12-29  (W) Nike Dunk Low Disrupt Carbon Green
# 136   240  150000  2021-07-28       (W) Nike Dunk Low Light Soft Pink
# 137   240  149000  2021-07-29       (W) Nike Dunk Low Light Soft Pink
# 138   230  142000  2021-07-30       (W) Nike Dunk Low Light Soft Pink
# 139   250  150000  2021-07-30       (W) Nike Dunk Low Light Soft Pink
# 140   235  150000  2021-07-30       (W) Nike Dunk Low Light Soft Pink
# 141   240  150000  2021-07-30       (W) Nike Dunk Low Light Soft Pink
# 142   235  149000  2021-07-31       (W) Nike Dunk Low Light Soft Pink
# 143   235  145000  2021-07-31       (W) Nike Dunk Low Light Soft Pink
# 144   250  134000  2021-08-01       (W) Nike Dunk Low Light Soft Pink
# 145   240  130000  2021-08-02       (W) Nike Dunk Low Light Soft Pink
# 146   245  122000  2021-08-02       (W) Nike Dunk Low Light Soft Pink
# 147   225  140000  2021-08-03       (W) Nike Dunk Low Light Soft Pink
# 148   245  135000  2021-08-03       (W) Nike Dunk Low Light Soft Pink
# 149   240  129000  2021-08-03       (W) Nike Dunk Low Light Soft Pink
#
#     release_date                              color  release_price brand  \
# 100   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 101   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 102   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 103   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 104   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 105   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 106   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 107   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 108   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 109   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 110   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 111   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 112   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 113   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 114   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 115   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 116   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 117   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 118   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 119   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 120   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 121   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 122   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 123   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 124   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 125   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 126   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 127   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 128   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 129   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 130   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 131   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 132   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 133   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 134   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 135   2021-10-21            SUMMITWHITE/CARBONGREEN         147400  Nike
# 136   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 137   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 138   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 139   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 140   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 141   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 142   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 143   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 144   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 145   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 146   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 147   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 148   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
# 149   2021-08-17  LIGHTSOFTPINK/GHOST-LIMEICE-WHITE         119000  Nike
#
#       category   number    wish  review  transactions type  review_log  \
# 100  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 101  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 102  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 103  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 104  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 105  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 106  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 107  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 108  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 109  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 110  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 111  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 112  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 113  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 114  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 115  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 116  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 117  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 118  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 119  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 120  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 121  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 122  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 123  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 124  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 125  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 126  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 127  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 128  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 129  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 130  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 131  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 132  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 133  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 134  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 135  Nike Dunk  43903.0  1290.0    10.0           106  Low    2.302585
# 136  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 137  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 138  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 139  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 140  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 141  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 142  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 143  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 144  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 145  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 146  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 147  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 148  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
# 149  Nike Dunk  37275.0  3642.0    93.0          1162  Low    4.532600
#
#      wish_log
# 100  7.162397
# 101  7.162397
# 102  7.162397
# 103  7.162397
# 104  7.162397
# 105  7.162397
# 106  7.162397
# 107  7.162397
# 108  7.162397
# 109  7.162397
# 110  7.162397
# 111  7.162397
# 112  7.162397
# 113  7.162397
# 114  7.162397
# 115  7.162397
# 116  7.162397
# 117  7.162397
# 118  7.162397
# 119  7.162397
# 120  7.162397
# 121  7.162397
# 122  7.162397
# 123  7.162397
# 124  7.162397
# 125  7.162397
# 126  7.162397
# 127  7.162397
# 128  7.162397
# 129  7.162397
# 130  7.162397
# 131  7.162397
# 132  7.162397
# 133  7.162397
# 134  7.162397
# 135  7.162397
# 136  8.200288
# 137  8.200288
# 138  8.200288
# 139  8.200288
# 140  8.200288
# 141  8.200288
# 142  8.200288
# 143  8.200288
# 144  8.200288
# 145  8.200288
# 146  8.200288
# 147  8.200288
# 148  8.200288
# 149  8.200288

# %%
sns.histplot(df['release_price'], bins=50)
# Out:
# <AxesSubplot:xlabel='release_price', ylabel='Count'>

# %% [markdown]
# ### size
# - size_target 컬럼 생성
# - size_type 컬럼 생성

# %%
# GS : grade school 초등학생 사이즈
# PS : Pre school 미취학 아동 사이즈
# TD : Toddler 유야용 사이즈
# W : Womans 여성 사이즈

# %%
df.loc[(df['product'].str.contains('(GS)',regex = False)) | (df['product'].str.contains('(W)',regex = False)), 'size_target'] = 'Female'
df.loc[(df['product'].str.contains('(PS)',regex = False)) | (df['product'].str.contains('(TD)',regex = False)), 'size_target'] = 'Kids'

# %%
df.loc[(df['size_target'] != 'Female') & (df['size_target'] != 'Kids'), 'size_target'] = 'Male'

# %%
df[['product', 'size_target']].value_counts()
# Out:
# product                                  size_target
# Nike Dunk Low Retro Black                Male           18150
# Nike Dunk Low SE Seoul                   Male            7758
# (W) Nike Dunk Low Black                  Female          6700
# Nike Dunk Low Retro University Blue      Male            4450
# Nike x Ambush Dunk High Deep Royal Blue  Male            4450
#                                                         ...
# Nike Dunk High Premium SB Flamingo       Male               1
# Nike Dunk High Premium Ultimate Glory    Male               1
# Nike Dunk High Pro SB Syracuse           Male               1
# Nike Dunk SB High Concept Car            Male               1
# Nike Dunk SB Low Gulf of Mexico          Male               1
# Length: 265, dtype: int64

# %%
df.loc[(df['product'].str.contains('(GS)',regex = False)), 'size_type'] = 'GS'
df.loc[(df['product'].str.contains('(W)',regex = False)), 'size_type'] = 'W'
df.loc[(df['product'].str.contains('(PS)',regex = False)), 'size_type'] = 'PS'
df.loc[(df['product'].str.contains('(TD)',regex = False)), 'size_type'] = 'TD'
df.loc[df['size_target'] == 'Male', 'size_type'] = 'M'

# %%
df[['product', 'size_type']].value_counts().head(20)
# Out:
# product                                    size_type
# Nike Dunk Low Retro Black                  M            18150
# Nike Dunk Low SE Seoul                     M             7758
# (W) Nike Dunk Low Black                    W             6700
# Nike Dunk Low Retro University Blue        M             4450
# Nike x Ambush Dunk High Deep Royal Blue    M             4450
# (W) Nike Dunk Low Light Bone               W             4400
# Nike x Kasina Dunk Low 80's Bus            M             4345
# (GS) Nike Dunk Low Black                   GS            4100
# Nike Dunk Low Retro Varsity Green          M             4050
# Nike x Off-White Dunk Low The 50 - Lot 18  M             3800
# Nike Dunk Low Retro Medium Grey            M             3107
# Nike x Off-White Dunk Low The 50 - Lot 46  M             3100
# Nike Dunk Low Retro Championship Red       M             3000
# (PS) Nike Dunk Low Black                   PS            2985
# (W) Nike Dunk High Black and White         W             2950
# Nike SB Dunk Low Pro Chicago               M             2900
# Nike Dunk High SP Varsity Maize            M             2900
# Nike Dunk High Retro Championship Navy     M             2853
# (W) Nike Dunk Low Next Nature Pale Coral   W             2837
# (W) Nike Dunk Low Triple White             W             2767
# dtype: int64

# %%
df[['size_target', 'size_type', 'product', 'size']]
# Out:
#        size_target size_type                             product  size
# 0           Female         W   (W) Nike Dunk Low SE Primal Black   245
# 1           Female         W   (W) Nike Dunk Low SE Primal Black   240
# 2           Female         W   (W) Nike Dunk Low SE Primal Black   245
# 3           Female         W   (W) Nike Dunk Low SE Primal Black   275
# 4           Female         W   (W) Nike Dunk Low SE Primal Black   240
# ...            ...       ...                                 ...   ...
# 214337      Female         W  (W) Nike Dunk High Black and White   240
# 214338      Female         W  (W) Nike Dunk High Black and White   235
# 214339      Female         W  (W) Nike Dunk High Black and White   255
# 214340      Female         W  (W) Nike Dunk High Black and White   245
# 214341      Female         W  (W) Nike Dunk High Black and White   245
#
# [214342 rows x 4 columns]

# %%
sns.histplot(df['size'])
# Out:
# <AxesSubplot:xlabel='size', ylabel='Count'>

# %% [markdown]
# ### color
# - color1, color2, color3, color4 추가
# - color_count 추가
# - multicolor 컬럼 추가
# - 색상은 price가 아닌 transactions와 연관이 있어보임.

# %%
df['color_count'] = df['color'].apply(lambda x : len(x.split('/')))

# %%
df['color_count'].value_counts()
# Out:
# 2    184223
# 3     24609
# 4      5149
# 1       361
# Name: color_count, dtype: int64

# %%
pd.pivot_table(df, index='color_count', values='price', aggfunc='mean')
# Out:
#                      price
# color_count
# 1            216576.177285
# 2            328402.664162
# 3            305124.344752
# 4            279925.228200

# %%
# 트리플 화이트 = 단색
# df[df['color'] == 'WHITE/WHITE/WHITE']

# %%
# df[df['color'] == 'BLACK/WHITE-RED-BLUE']

# %%
# df[df['color'] == 'WHITE/MULTI-COLOR/WHITE']

# %%
# multicolor가 아닌 것은 가격대가 낮다
df.loc[df['color_count']==1, 'multicolor'] = False
df.loc[df['color_count']!=1, 'multicolor'] = True
df.loc[df['color'] == 'WHITE/WHITE/WHITE', 'multicolor'] = False

# %%
df['multicolor'].value_counts()
# Out:
# True     211214
# False      3128
# Name: multicolor, dtype: int64

# %%
pd.pivot_table(df, index='multicolor', values='price', aggfunc='median')
# Out:
#              price
# multicolor
# False       129000
# True        259000

# %%
df[df['color_count']==3]['color'].value_counts().head(50)
# Out:
# WHITE/TEAMGREEN/ORANGE                4050
# MEDIUMGREY/VARSITYRED/WHITE           3118
# WHITE/WHITE/WHITE                     2767
# WHITE/BLACK/SPRUCEAURA                2688
# BLUEVOID/GREYFOG/WHITE                2081
# SAIL/MEDIUMCURRY/FOSSIL               2000
# SAIL/COAST/UNIVERSITYGOLD             1550
# WHITE/PHOTONDUST/WHITE                1449
# WHITE/GREENGLOW/SUNSETPULSE           1417
# SAIL/TEAMRED/PALEIVORY                 994
# BLACK/PUREPLATINUM/ANTHRACITE          631
# NAVY/UNIVERSITYGOLD/GYMRED             483
# MIDASGOLD/TOUGHRED/WHITE               385
# BLACK/WHITE/MULTI                      263
# WHITE/MULTI-COLOR/WHITE                250
# SUMMITWHITE/DESERTSAND/GHOSTSAIL       208
# WHITE/METALLICGOLD/BARKROOTBROWN       158
# BLACK/MULTI-COLOR/BLACK                 30
# CASHMERE/GREENNOISE/PALECORAL           25
# SUNSETPULSE/SILVER/PURPLEPULSE          15
# WHITE/METALLICSILVER/WHITE              15
# WHITE/WHITE/METALLICGOLD                13
# UNIVERSITYGOLD/WHITE/LIGHTGUMBROWN      13
# ANTHRACITE/WHITE/BLACK                   6
# Name: color, dtype: int64

# %%
df[['product','color']].value_counts().head(10)
# Out:
# product                                    color
# Nike Dunk Low Retro Black                  WHITE/BLACK                            18150
# Nike Dunk Low SE Seoul                     BLACK/WHITE-RED-BLUE                    7758
# (W) Nike Dunk Low Black                    WHITE/BLACK                             6700
# Nike Dunk Low Retro University Blue        WHITE/UNIVERSITYBLUE-WHITE              4450
# Nike x Ambush Dunk High Deep Royal Blue    DEEPROYALBLUE/WHITE-PALEIVORY-BLACK     4450
# (W) Nike Dunk Low Light Bone               SAIL/LIGHTBONE-CASHMERE                 4400
# Nike x Kasina Dunk Low 80's Bus            SAIL/UNIVERSITYGOLD-INDUSTRIALBLUE      4345
# (GS) Nike Dunk Low Black                   WHITE/BLACK                             4100
# Nike Dunk Low Retro Varsity Green          WHITE/TEAMGREEN/ORANGE                  4050
# Nike x Off-White Dunk Low The 50 - Lot 18  SAIL/NEUTRALGREY                        3800
# dtype: int64

# %%
def color_slash(x):
    if x.count('/') == 0:
        return x + '///'
    elif x.count('/') == 1:
        return x + '//'
    elif x.count('/') == 2:
        return x + '/'
    elif x.count('/') == 3:
        return x

# %%
df['color_list'] = df['color'].apply(color_slash).apply(lambda x : x.split('/'))

# %%
df.head(3)
# Out:
#    size   price        date                            product release_date  \
# 0   245  125000  2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 1   240  123000  2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 2   245  129000  2021-10-01  (W) Nike Dunk Low SE Primal Black   2021-11-07
#
#                      color  release_price brand   category   number  wish  \
# 0  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 1  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 2  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
#
#    review  transactions type  review_log  wish_log size_target size_type  \
# 0     4.0            30  Low    1.386295    4.5326      Female         W
# 1     4.0            30  Low    1.386295    4.5326      Female         W
# 2     4.0            30  Low    1.386295    4.5326      Female         W
#
#    color_count multicolor                     color_list
# 0            3       True  [BLACK, MULTI-COLOR, BLACK, ]
# 1            3       True  [BLACK, MULTI-COLOR, BLACK, ]
# 2            3       True  [BLACK, MULTI-COLOR, BLACK, ]

# %%
df['color_list'].apply(lambda x: len(x)).value_counts()
# Out:
# 4    214342
# Name: color_list, dtype: int64

# %%
df['color1'] = df['color_list'].apply(lambda x : x[0])
df['color2'] = df['color_list'].apply(lambda x : x[1])
df['color3'] = df['color_list'].apply(lambda x : x[2])
df['color4'] = df['color_list'].apply(lambda x : x[3])

# %%
df = df.drop(['color_list'], axis=1)

# %% [markdown]
# ### Collabo
# - Collabo 컬럼 생성
# - Collabo_brand 컬럼 생성
# - Collabo_class 컬럼 생성

# %%
df['product'].value_counts()
# Out:
# Nike Dunk Low Retro Black                  18150
# Nike Dunk Low SE Seoul                      7758
# (W) Nike Dunk Low Black                     6700
# Nike Dunk Low Retro University Blue         4450
# Nike x Ambush Dunk High Deep Royal Blue     4450
#                                            ...
# (W) Nike Dunk High University Gold             1
# Nike Dunk SB High Concept Car                  1
# Nike Dunk High Kentucky                        1
# (GS) Nike Dunk High Knicks                     1
# Nike Dunk SB High Black Purple Box             1
# Name: product, Length: 265, dtype: int64

# %%
df['Collabo'] = df['product'].str.contains(' x ', regex=False)

# %%
df['Collabo'].value_counts()
# Out:
# False    177100
# True      37242
# Name: Collabo, dtype: int64

# %%
df[df['Collabo'].isnull()]
# Out:
# Empty DataFrame
# Columns: [size, price, date, product, release_date, color, release_price, brand, category, number, wish, review, transactions, type, review_log, wish_log, size_target, size_type, color_count, multicolor, color1, color2, color3, color4, Collabo]
# Index: []

# %%
pd.set_option('display.float_format','{:.0f}'.format)

# %%
pd.pivot_table(df[df['Collabo']==True], index=['product'], values='price', aggfunc='mean').sort_values(by='price', ascending=False)
# Out:
#                                                      price
# product
# Nike x Travis Scott SB Dunk Low                    2093267
# Nike x Supreme SB Dunk Low Barkroot Brown          1446633
# Nike x Off-White Dunk Low The 50 - Lot 1           1330911
# Nike x StrangeLove SB Dunk Low Pink (Regular Box)  1313798
# Nike x Frame Skate SB Dunk Low Pro Habibi          1245188
# Nike x Off-White Dunk Low The 50 - Lot 50          1075585
# Nike x Kasina Dunk Low Road Sign - Kasina Exclu... 1023193
# Nike x Off-White Dunk Low Pine Green                909133
# Nike x Kasina Dunk Low 80's Bus                     782716
# Nike x Off-White Dunk Low The 50 - Lot 49           678877
# Nike x Off-White Dunk Low University Gold Midni...  654571
# Nike x Off-White Dunk Low The 50 - Lot 31           646667
# Nike x Ambush Dunk High Black                       632600
# Nike x Off-White Dunk Low University Red            617932
# Nike x Off-White Dunk Low The 50 - Lot 18           593514
# Nike x Ambush Dunk High Deep Royal Blue             562584
# Nike x Off-White Dunk Low The 50 - Lot 20           550222
# Nike x Parra SB Dunk Low Pro Abstract Art           441431
# Nike x Off-White Dunk Low The 50 - Lot 46           440160
# Nike x NBA Dunk Low Retro EMB Chicago               340556
# Nike x Quartersnacks SB Dunk Low Zebra Cake         313855
# Nike x NBA Dunk Low Retro EMB Nets                  270508
# Nike x Ambush Dunk High Flash Lime                  238662
# Nike x Fragment Dunk High Black                     210002
# (GS) Nike x NBA Dunk Low Nets                       202575
# Nike x Undercover Dunk High 1985 Gym Red            191773
# (GS) Nike x NBA Dunk Low Chicago                    167649

# %%
df.loc[df['Collabo'] ,['product','Collabo']].value_counts()
# Out:
# product                                                  Collabo
# Nike x Ambush Dunk High Deep Royal Blue                  True       4450
# Nike x Kasina Dunk Low 80's Bus                          True       4345
# Nike x Off-White Dunk Low The 50 - Lot 18                True       3800
# Nike x Off-White Dunk Low The 50 - Lot 46                True       3100
# Nike x Ambush Dunk High Black                            True       2688
# Nike x Ambush Dunk High Flash Lime                       True       2364
# Nike x Kasina Dunk Low Road Sign - Kasina Exclusive      True       1900
# Nike x Travis Scott SB Dunk Low                          True       1450
# Nike x Parra SB Dunk Low Pro Abstract Art                True       1450
# Nike x Undercover Dunk High 1985 Gym Red                 True       1450
# Nike x Fragment Dunk High Black                          True       1450
# Nike x NBA Dunk Low Retro EMB Nets                       True       1350
# Nike x NBA Dunk Low Retro EMB Chicago                    True       1006
# Nike x Off-White Dunk Low Pine Green                     True        905
# Nike x Off-White Dunk Low University Red                 True        853
# Nike x Off-White Dunk Low University Gold Midnight Navy  True        842
# (GS) Nike x NBA Dunk Low Chicago                         True        800
# (GS) Nike x NBA Dunk Low Nets                            True        731
# Nike x StrangeLove SB Dunk Low Pink (Regular Box)        True        526
# Nike x Frame Skate SB Dunk Low Pro Habibi                True        483
# Nike x Off-White Dunk Low The 50 - Lot 1                 True        327
# Nike x Off-White Dunk Low The 50 - Lot 49                True        318
# Nike x Off-White Dunk Low The 50 - Lot 50                True        246
# Nike x Supreme SB Dunk Low Barkroot Brown                True        158
# Nike x Quartersnacks SB Dunk Low Zebra Cake              True        145
# Nike x Off-White Dunk Low The 50 - Lot 20                True         99
# Nike x Off-White Dunk Low The 50 - Lot 31                True          6
# dtype: int64

# %%
df.loc[df['Collabo']==True, 'product'][6162].find('SB') != -1
# Out:
# True

# %%
df.loc[df['Collabo']==True, 'product'].value_counts()
# Out:
# Nike x Ambush Dunk High Deep Royal Blue                    4450
# Nike x Kasina Dunk Low 80's Bus                            4345
# Nike x Off-White Dunk Low The 50 - Lot 18                  3800
# Nike x Off-White Dunk Low The 50 - Lot 46                  3100
# Nike x Ambush Dunk High Black                              2688
# Nike x Ambush Dunk High Flash Lime                         2364
# Nike x Kasina Dunk Low Road Sign - Kasina Exclusive        1900
# Nike x Fragment Dunk High Black                            1450
# Nike x Travis Scott SB Dunk Low                            1450
# Nike x Undercover Dunk High 1985 Gym Red                   1450
# Nike x Parra SB Dunk Low Pro Abstract Art                  1450
# Nike x NBA Dunk Low Retro EMB Nets                         1350
# Nike x NBA Dunk Low Retro EMB Chicago                      1006
# Nike x Off-White Dunk Low Pine Green                        905
# Nike x Off-White Dunk Low University Red                    853
# Nike x Off-White Dunk Low University Gold Midnight Navy     842
# (GS) Nike x NBA Dunk Low Chicago                            800
# (GS) Nike x NBA Dunk Low Nets                               731
# Nike x StrangeLove SB Dunk Low Pink (Regular Box)           526
# Nike x Frame Skate SB Dunk Low Pro Habibi                   483
# Nike x Off-White Dunk Low The 50 - Lot 1                    327
# Nike x Off-White Dunk Low The 50 - Lot 49                   318
# Nike x Off-White Dunk Low The 50 - Lot 50                   246
# Nike x Supreme SB Dunk Low Barkroot Brown                   158
# Nike x Quartersnacks SB Dunk Low Zebra Cake                 145
# Nike x Off-White Dunk Low The 50 - Lot 20                    99
# Nike x Off-White Dunk Low The 50 - Lot 31                     6
# Name: product, dtype: int64

# %%
df[(df['type']=='Low')&(df['Collabo']==True)]['product'].value_counts()
# Out:
# Nike x Kasina Dunk Low 80's Bus                            4345
# Nike x Off-White Dunk Low The 50 - Lot 18                  3800
# Nike x Off-White Dunk Low The 50 - Lot 46                  3100
# Nike x Kasina Dunk Low Road Sign - Kasina Exclusive        1900
# Nike x Parra SB Dunk Low Pro Abstract Art                  1450
# Nike x Travis Scott SB Dunk Low                            1450
# Nike x NBA Dunk Low Retro EMB Nets                         1350
# Nike x NBA Dunk Low Retro EMB Chicago                      1006
# Nike x Off-White Dunk Low Pine Green                        905
# Nike x Off-White Dunk Low University Red                    853
# Nike x Off-White Dunk Low University Gold Midnight Navy     842
# (GS) Nike x NBA Dunk Low Chicago                            800
# (GS) Nike x NBA Dunk Low Nets                               731
# Nike x StrangeLove SB Dunk Low Pink (Regular Box)           526
# Nike x Frame Skate SB Dunk Low Pro Habibi                   483
# Nike x Off-White Dunk Low The 50 - Lot 1                    327
# Nike x Off-White Dunk Low The 50 - Lot 49                   318
# Nike x Off-White Dunk Low The 50 - Lot 50                   246
# Nike x Supreme SB Dunk Low Barkroot Brown                   158
# Nike x Quartersnacks SB Dunk Low Zebra Cake                 145
# Nike x Off-White Dunk Low The 50 - Lot 20                    99
# Nike x Off-White Dunk Low The 50 - Lot 31                     6
# Name: product, dtype: int64

# %%
df[(df['type']=='High')&(df['Collabo']==True)]['product'].value_counts()
# Out:
# Nike x Ambush Dunk High Deep Royal Blue     4450
# Nike x Ambush Dunk High Black               2688
# Nike x Ambush Dunk High Flash Lime          2364
# Nike x Undercover Dunk High 1985 Gym Red    1450
# Nike x Fragment Dunk High Black             1450
# Name: product, dtype: int64

# %%
def extract_collabo(x):
    if x.find('Low') != -1:
        if x.find('SB') != -1:
            r1 = x.find('Nike')
            r2 = x.find('SB')
            return x[r1+7:r2-1]
        elif x.find('SB') == -1:
            r1 = x.find('Nike')
            r2 = x.find('Dunk')
            return x[r1+7:r2-1]
    elif x.find('High') != -1:
        r1 = x.find('Nike')
        r2 = x.find('Dunk')
        return x[r1+7:r2-1]

# %%
df.loc[df['Collabo']==True, 'product'].apply(extract_collabo).value_counts()
# Out:
# Off-White        10496
# Ambush            9502
# Kasina            6245
# NBA               3887
# Fragment          1450
# Travis Scott      1450
# Undercover        1450
# Parra             1450
# StrangeLove        526
# Frame Skate        483
# Supreme            158
# Quartersnacks      145
# Name: product, dtype: int64

# %%
df['Collabo_brand'] = df.loc[df['Collabo']==True, 'product'].apply(extract_collabo)

# %%
df.loc[df['Collabo']==False, 'Collabo_brand'] = 'None'

# %%
df.loc[df['Collabo']==True]
# Out:
#         size   price        date                                      product  \
# 6162     270  410000  2021-09-01  Nike x Quartersnacks SB Dunk Low Zebra Cake
# 6163     260  400000  2021-09-01  Nike x Quartersnacks SB Dunk Low Zebra Cake
# 6164     260  300000  2021-09-01  Nike x Quartersnacks SB Dunk Low Zebra Cake
# 6165     260  300000  2021-09-01  Nike x Quartersnacks SB Dunk Low Zebra Cake
# 6166     270  330000  2021-09-01  Nike x Quartersnacks SB Dunk Low Zebra Cake
# ...      ...     ...         ...                                          ...
# 209978   265  860000  2022-01-06                Nike x Ambush Dunk High Black
# 209979   275  885000  2022-01-06                Nike x Ambush Dunk High Black
# 209980   275  873000  2022-01-06                Nike x Ambush Dunk High Black
# 209981   270  863000  2022-01-06                Nike x Ambush Dunk High Black
# 209982   240  621000  2022-01-07                Nike x Ambush Dunk High Black
#
#        release_date                   color  release_price brand   category  \
# 6162     2021-09-01             BLACK/WHITE         129000  Nike  Nike Dunk
# 6163     2021-09-01             BLACK/WHITE         129000  Nike  Nike Dunk
# 6164     2021-09-01             BLACK/WHITE         129000  Nike  Nike Dunk
# 6165     2021-09-01             BLACK/WHITE         129000  Nike  Nike Dunk
# 6166     2021-09-01             BLACK/WHITE         129000  Nike  Nike Dunk
# ...             ...                     ...            ...   ...        ...
# 209978   2020-12-11  WHITE/BLACK/SPRUCEAURA         219000  Nike  Nike Dunk
# 209979   2020-12-11  WHITE/BLACK/SPRUCEAURA         219000  Nike  Nike Dunk
# 209980   2020-12-11  WHITE/BLACK/SPRUCEAURA         219000  Nike  Nike Dunk
# 209981   2020-12-11  WHITE/BLACK/SPRUCEAURA         219000  Nike  Nike Dunk
# 209982   2020-12-11  WHITE/BLACK/SPRUCEAURA         219000  Nike  Nike Dunk
#
#         number  wish  review  transactions  type  review_log  wish_log  \
# 6162     39064   783      26           145   Low           3         7
# 6163     39064   783      26           145   Low           3         7
# 6164     39064   783      26           145   Low           3         7
# 6165     39064   783      26           145   Low           3         7
# 6166     39064   783      26           145   Low           3         7
# ...        ...   ...     ...           ...   ...         ...       ...
# 209978   26706  6957    1609          2688  High           7         9
# 209979   26706  6957    1609          2688  High           7         9
# 209980   26706  6957    1609          2688  High           7         9
# 209981   26706  6957    1609          2688  High           7         9
# 209982   26706  6957    1609          2688  High           7         9
#
#        size_target size_type  color_count multicolor color1 color2  \
# 6162          Male         M            2       True  BLACK  WHITE
# 6163          Male         M            2       True  BLACK  WHITE
# 6164          Male         M            2       True  BLACK  WHITE
# 6165          Male         M            2       True  BLACK  WHITE
# 6166          Male         M            2       True  BLACK  WHITE
# ...            ...       ...          ...        ...    ...    ...
# 209978        Male         M            3       True  WHITE  BLACK
# 209979        Male         M            3       True  WHITE  BLACK
# 209980        Male         M            3       True  WHITE  BLACK
# 209981        Male         M            3       True  WHITE  BLACK
# 209982        Male         M            3       True  WHITE  BLACK
#
#             color3 color4  Collabo  Collabo_brand
# 6162                          True  Quartersnacks
# 6163                          True  Quartersnacks
# 6164                          True  Quartersnacks
# 6165                          True  Quartersnacks
# 6166                          True  Quartersnacks
# ...            ...    ...      ...            ...
# 209978  SPRUCEAURA            True         Ambush
# 209979  SPRUCEAURA            True         Ambush
# 209980  SPRUCEAURA            True         Ambush
# 209981  SPRUCEAURA            True         Ambush
# 209982  SPRUCEAURA            True         Ambush
#
# [37242 rows x 26 columns]

# %%
# df[df['product'].str.contains('S.P.O.T. x Lance Mountain Dunk')]['product']

# %%
# df[df['product'].str.contains('S.P.O.T. x Lance Mountain Dunk')]['Collabo_brand'] = 'S.P.O.T. x Lance Mountain'

# %%
# df[df['product'].str.contains('S.P.O.T. x Lance Mountain Dunk')]['Collabo_brand']

# %%
df.groupby('Collabo_brand')['price'].agg(['mean', 'count']).sort_values(by='mean')
# Out:
#                  mean   count
# Collabo_brand
# Undercover     191773    1450
# Fragment       210002    1450
# NBA            254692    3887
# None           260334  177100
# Quartersnacks  313855     145
# Parra          441431    1450
# Ambush         501802    9502
# Off-White      618797   10496
# Kasina         855879    6245
# Frame Skate   1245188     483
# StrangeLove   1313798     526
# Supreme       1446633     158
# Travis Scott  2093267    1450

# %%
df.loc[df['Collabo_brand'] == 'Off-White'].groupby('product')['price'].agg(['mean', 'count']).sort_values(by='mean')
# Out:
#                                                       mean  count
# product
# Nike x Off-White Dunk Low The 50 - Lot 46           440160   3100
# Nike x Off-White Dunk Low The 50 - Lot 20           550222     99
# Nike x Off-White Dunk Low The 50 - Lot 18           593514   3800
# Nike x Off-White Dunk Low University Red            617932    853
# Nike x Off-White Dunk Low The 50 - Lot 31           646667      6
# Nike x Off-White Dunk Low University Gold Midni...  654571    842
# Nike x Off-White Dunk Low The 50 - Lot 49           678877    318
# Nike x Off-White Dunk Low Pine Green                909133    905
# Nike x Off-White Dunk Low The 50 - Lot 50          1075585    246
# Nike x Off-White Dunk Low The 50 - Lot 1           1330911    327

# %%
df.loc[df['Collabo']==True, ['product','Collabo_brand']].value_counts()
# Out:
# product                                                  Collabo_brand
# Nike x Ambush Dunk High Deep Royal Blue                  Ambush           4450
# Nike x Kasina Dunk Low 80's Bus                          Kasina           4345
# Nike x Off-White Dunk Low The 50 - Lot 18                Off-White        3800
# Nike x Off-White Dunk Low The 50 - Lot 46                Off-White        3100
# Nike x Ambush Dunk High Black                            Ambush           2688
# Nike x Ambush Dunk High Flash Lime                       Ambush           2364
# Nike x Kasina Dunk Low Road Sign - Kasina Exclusive      Kasina           1900
# Nike x Travis Scott SB Dunk Low                          Travis Scott     1450
# Nike x Parra SB Dunk Low Pro Abstract Art                Parra            1450
# Nike x Undercover Dunk High 1985 Gym Red                 Undercover       1450
# Nike x Fragment Dunk High Black                          Fragment         1450
# Nike x NBA Dunk Low Retro EMB Nets                       NBA              1350
# Nike x NBA Dunk Low Retro EMB Chicago                    NBA              1006
# Nike x Off-White Dunk Low Pine Green                     Off-White         905
# Nike x Off-White Dunk Low University Red                 Off-White         853
# Nike x Off-White Dunk Low University Gold Midnight Navy  Off-White         842
# (GS) Nike x NBA Dunk Low Chicago                         NBA               800
# (GS) Nike x NBA Dunk Low Nets                            NBA               731
# Nike x StrangeLove SB Dunk Low Pink (Regular Box)        StrangeLove       526
# Nike x Frame Skate SB Dunk Low Pro Habibi                Frame Skate       483
# Nike x Off-White Dunk Low The 50 - Lot 1                 Off-White         327
# Nike x Off-White Dunk Low The 50 - Lot 49                Off-White         318
# Nike x Off-White Dunk Low The 50 - Lot 50                Off-White         246
# Nike x Supreme SB Dunk Low Barkroot Brown                Supreme           158
# Nike x Quartersnacks SB Dunk Low Zebra Cake              Quartersnacks     145
# Nike x Off-White Dunk Low The 50 - Lot 20                Off-White          99
# Nike x Off-White Dunk Low The 50 - Lot 31                Off-White           6
# dtype: int64

# %%
# # 브랜드 카테고리 분류 (기준을 정확히 잡아야 함)
# def make_class(x):
#     if x in ['NBA', 'Quartersnacks', 'Parra']:
#         return 'Normal'
#     elif x in ['Off-White', 'Kasina']:
#         return 'Preminum'
#     elif x in ['Frame Skate', 'StrangeLove', 'Supreme', 'Travis Scott']:
#         return 'Highend'
#     else:
#         return 'None'

# %%
# df.loc[df['Collabo_brand'].apply(make_class) == 'Normal', 'Collabo_class'] = 'Normal'
# df.loc[df['Collabo_brand'].apply(make_class) == 'Preminum', 'Collabo_class'] = 'Preminum'
# df.loc[df['Collabo_brand'].apply(make_class) == 'Highend', 'Collabo_class'] = 'Highend'
# df.loc[df['Collabo_brand'].apply(make_class) == 'None', 'Collabo_class'] = 'None'

# %%
# df[['product','Collabo_brand', 'Collabo_class']].value_counts()

# %% [markdown]
# ### date
# - after_day 컬럼 생성
# - date, release_date : unix 타임스탬프 형식으로 변환

# %%
df['date']
# Out:
# 0         2021-09-30
# 1         2021-09-30
# 2         2021-10-01
# 3         2021-10-04
# 4         2021-10-04
#              ...
# 214337    2022-01-06
# 214338    2022-01-06
# 214339    2022-01-06
# 214340    2022-01-07
# 214341    2022-01-07
# Name: date, Length: 214342, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'])
df['release_date'] = pd.to_datetime(df['release_date'])

# %%
print(df.shape)
df.head()
# Out:
# (214342, 26)
#    size   price       date                            product release_date  \
# 0   245  125000 2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 1   240  123000 2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 2   245  129000 2021-10-01  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 3   275  129000 2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 4   240  132000 2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
#
#                      color  release_price brand   category  number  wish  \
# 0  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
# 1  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
# 2  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
# 3  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
# 4  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
#
#    review  transactions type  review_log  wish_log size_target size_type  \
# 0       4            30  Low           1         5      Female         W
# 1       4            30  Low           1         5      Female         W
# 2       4            30  Low           1         5      Female         W
# 3       4            30  Low           1         5      Female         W
# 4       4            30  Low           1         5      Female         W
#
#    color_count multicolor color1       color2 color3 color4  Collabo  \
# 0            3       True  BLACK  MULTI-COLOR  BLACK           False
# 1            3       True  BLACK  MULTI-COLOR  BLACK           False
# 2            3       True  BLACK  MULTI-COLOR  BLACK           False
# 3            3       True  BLACK  MULTI-COLOR  BLACK           False
# 4            3       True  BLACK  MULTI-COLOR  BLACK           False
#
#   Collabo_brand
# 0          None
# 1          None
# 2          None
# 3          None
# 4          None

# %%
df['after_day'] = df['date'] - df['release_date']

# %%
df['after_day'] = df['after_day'].dt.days

# %%
df
# Out:
#         size   price       date                             product  \
# 0        245  125000 2021-09-30   (W) Nike Dunk Low SE Primal Black
# 1        240  123000 2021-09-30   (W) Nike Dunk Low SE Primal Black
# 2        245  129000 2021-10-01   (W) Nike Dunk Low SE Primal Black
# 3        275  129000 2021-10-04   (W) Nike Dunk Low SE Primal Black
# 4        240  132000 2021-10-04   (W) Nike Dunk Low SE Primal Black
# ...      ...     ...        ...                                 ...
# 214337   240  238000 2022-01-06  (W) Nike Dunk High Black and White
# 214338   235  223000 2022-01-06  (W) Nike Dunk High Black and White
# 214339   255  260000 2022-01-06  (W) Nike Dunk High Black and White
# 214340   245  248000 2022-01-07  (W) Nike Dunk High Black and White
# 214341   245  268000 2022-01-07  (W) Nike Dunk High Black and White
#
#        release_date                      color  release_price brand  \
# 0        2021-11-07    BLACK/MULTI-COLOR/BLACK         129000  Nike
# 1        2021-11-07    BLACK/MULTI-COLOR/BLACK         129000  Nike
# 2        2021-11-07    BLACK/MULTI-COLOR/BLACK         129000  Nike
# 3        2021-11-07    BLACK/MULTI-COLOR/BLACK         129000  Nike
# 4        2021-11-07    BLACK/MULTI-COLOR/BLACK         129000  Nike
# ...             ...                        ...            ...   ...
# 214337   2021-05-01  WHITE/BLACK-UNIVERSITYRED         129000  Nike
# 214338   2021-05-01  WHITE/BLACK-UNIVERSITYRED         129000  Nike
# 214339   2021-05-01  WHITE/BLACK-UNIVERSITYRED         129000  Nike
# 214340   2021-05-01  WHITE/BLACK-UNIVERSITYRED         129000  Nike
# 214341   2021-05-01  WHITE/BLACK-UNIVERSITYRED         129000  Nike
#
#          category  number  wish  review  transactions  type  review_log  \
# 0       Nike Dunk   41947    93       4            30   Low           1
# 1       Nike Dunk   41947    93       4            30   Low           1
# 2       Nike Dunk   41947    93       4            30   Low           1
# 3       Nike Dunk   41947    93       4            30   Low           1
# 4       Nike Dunk   41947    93       4            30   Low           1
# ...           ...     ...   ...     ...           ...   ...         ...
# 214337  Nike Dunk   33866  9875     268          2950  High           6
# 214338  Nike Dunk   33866  9875     268          2950  High           6
# 214339  Nike Dunk   33866  9875     268          2950  High           6
# 214340  Nike Dunk   33866  9875     268          2950  High           6
# 214341  Nike Dunk   33866  9875     268          2950  High           6
#
#         wish_log size_target size_type  color_count multicolor color1  \
# 0              5      Female         W            3       True  BLACK
# 1              5      Female         W            3       True  BLACK
# 2              5      Female         W            3       True  BLACK
# 3              5      Female         W            3       True  BLACK
# 4              5      Female         W            3       True  BLACK
# ...          ...         ...       ...          ...        ...    ...
# 214337         9      Female         W            2       True  WHITE
# 214338         9      Female         W            2       True  WHITE
# 214339         9      Female         W            2       True  WHITE
# 214340         9      Female         W            2       True  WHITE
# 214341         9      Female         W            2       True  WHITE
#
#                      color2 color3 color4  Collabo Collabo_brand  after_day
# 0               MULTI-COLOR  BLACK           False          None        -38
# 1               MULTI-COLOR  BLACK           False          None        -38
# 2               MULTI-COLOR  BLACK           False          None        -37
# 3               MULTI-COLOR  BLACK           False          None        -34
# 4               MULTI-COLOR  BLACK           False          None        -34
# ...                     ...    ...    ...      ...           ...        ...
# 214337  BLACK-UNIVERSITYRED                  False          None        250
# 214338  BLACK-UNIVERSITYRED                  False          None        250
# 214339  BLACK-UNIVERSITYRED                  False          None        250
# 214340  BLACK-UNIVERSITYRED                  False          None        251
# 214341  BLACK-UNIVERSITYRED                  False          None        251
#
# [214342 rows x 27 columns]

# %%
# after_day >= 0 만 선택
df = df[df['after_day'] >= 1]

# %%
sns.histplot(df['after_day'])
# Out:
# <AxesSubplot:xlabel='after_day', ylabel='Count'>

# %%
sns.histplot(np.log(df['after_day']+0.000001))
# Out:
# <AxesSubplot:xlabel='after_day', ylabel='Count'>

# %%
df['after_day_log'] = np.log(df['after_day'] + 0.000001)

# %%
df[df['after_day'] == 0].groupby('product')['price'].mean().sort_values(ascending=False).head(5)
# Out:
# Series([], Name: price, dtype: int64)

# %%
df[df['after_day'] == 1].groupby('product')['price'].mean().sort_values(ascending=False).head(5)
# Out:
# product
# Nike x Kasina Dunk Low Road Sign - Kasina Exclusive   1511909
# Nike SB Dunk Low Pro Chicago                          1205000
# Nike SB Dunk Low Pro Street Hawker                    1194429
# Nike SB Dunk Low What The Paul                         760459
# Nike x Ambush Dunk High Deep Royal Blue                710379
# Name: price, dtype: float64

# %%
import datetime as dt
# 유닉스 타임스탬프로 바꾸기
df['date_unix'] = df['date'].map(dt.datetime.toordinal)
df['release_date_unix'] = df['release_date'].map(dt.datetime.toordinal)

# %% [markdown]
# ### Correlation

# %%
df.head(1)
# Out:
#     size   price       date                            product release_date  \
# 18   235  124000 2021-11-14  (W) Nike Dunk Low SE Primal Black   2021-11-07
#
#                       color  release_price brand   category  number  wish  \
# 18  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
#
#     review  transactions type  review_log  wish_log size_target size_type  \
# 18       4            30  Low           1         5      Female         W
#
#     color_count multicolor color1       color2 color3 color4  Collabo  \
# 18            3       True  BLACK  MULTI-COLOR  BLACK           False
#
#    Collabo_brand  after_day  after_day_log  date_unix  release_date_unix
# 18          None          7              2     738108             738101

# %%
heatmap_data = df[["price", "size", "date_unix", "release_date_unix", "release_price", "wish", "review", "transactions", 'after_day', 'Collabo', 'color_count', 'multicolor', 'review_log', 'wish_log', 'after_day_log']]

# %%
colormap = plt.cm.PuBu
plt.figure(figsize=(16, 12))
plt.title("Person Correlation of Features", y = 1.05, size = 15)
sns.heatmap(heatmap_data.astype(float).corr(), linewidths = 0.1, vmax = 1.0
            , square = True, cmap = colormap, linecolor = "white", annot = True, annot_kws = {"size" : 16})
# Out:
# <AxesSubplot:title={'center':'Person Correlation of Features'}>

# %% [markdown]
# #### price (Target)

# %%
sns.histplot(df['price'])
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
df.describe()
# Out:
#         size   price  release_price  number   wish  review  transactions  \
# count 197162  197162         197162  197162 197162  197162        197162
# mean     255  328441         130929   32671  11577    1134          3677
# std       24  258408          32850    5903  13987    2037          4553
# min       80   34000          59000    3490      4       0             1
# 25%      240  183000         119000   28029   2883     141          1259
# 50%      260  257000         119000   32656   6665     347          2161
# 75%      270  375000         129000   38282  12000    1061          4100
# max      320 3000000         227200   47901  52000    7820         18150
#
#        review_log  wish_log  color_count  after_day  after_day_log  date_unix  \
# count      197162    197162       197162     197162         197162     197162
# mean            6         9            2         80              3     737951
# std             2         1            0        120              2        137
# min           -14         1            1          1              0     737454
# 25%             5         8            2         10              2     737861
# 50%             6         9            2         46              4     737953
# 75%             7         9            2        103              5     738066
# max             9        11            4       5573              9     738162
#
#        release_date_unix
# count             197162
# mean              737871
# std                  165
# min               732220
# 25%               737794
# 50%               737906
# 75%               738011
# max               738153

# %%
sns.histplot(np.log(df['price']+0.000001))
# Out:
# <AxesSubplot:xlabel='price', ylabel='Count'>

# %%
df = df.reset_index(drop=True)

# %%
df.to_csv('data/nike_dunk(model).csv')

# %%
df.head(1)
# Out:
#    size   price       date                            product release_date  \
# 0   235  124000 2021-11-14  (W) Nike Dunk Low SE Primal Black   2021-11-07
#
#                      color  release_price brand   category  number  wish  \
# 0  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
#
#    review  transactions type  review_log  wish_log size_target size_type  \
# 0       4            30  Low           1         5      Female         W
#
#    color_count multicolor color1       color2 color3 color4  Collabo  \
# 0            3       True  BLACK  MULTI-COLOR  BLACK           False
#
#   Collabo_brand  after_day  after_day_log  date_unix  release_date_unix
# 0          None          7              2     738108             738101

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 197162 entries, 18 to 214341
# Data columns (total 30 columns):
#  #   Column             Non-Null Count   Dtype
# ---  ------             --------------   -----
#  0   size               197162 non-null  int64
#  1   price              197162 non-null  int64
#  2   date               197162 non-null  datetime64[ns]
#  3   product            197162 non-null  object
#  4   release_date       197162 non-null  datetime64[ns]
#  5   color              197162 non-null  object
#  6   release_price      197162 non-null  int64
#  7   brand              197162 non-null  object
#  8   category           197162 non-null  object
#  9   number             197162 non-null  float64
#  10  wish               197162 non-null  float64
#  11  review             197162 non-null  float64
#  12  transactions       197162 non-null  int64
#  13  type               197162 non-null  object
#  14  review_log         197162 non-null  float64
#  15  wish_log           197162 non-null  float64
#  16  size_target        197162 non-null  object
#  17  size_type          197162 non-null  object
#  18  color_count        197162 non-null  int64
#  19  multicolor         197162 non-null  object
#  20  color1             197162 non-null  object
#  21  color2             197162 non-null  object
#  22  color3             197162 non-null  object
#  23  color4             197162 non-null  object
#  24  Collabo            197162 non-null  bool
#  25  Collabo_brand      197162 non-null  object
#  26  after_day          197162 non-null  int64
#  27  after_day_log      197162 non-null  float64
#  28  date_unix          197162 non-null  int64
#  29  release_date_unix  197162 non-null  int64
# dtypes: bool(1), datetime64[ns](2), float64(6), int64(8), object(13)
# memory usage: 45.3+ MB

# %% [markdown]
# ### Drop Duplicates
# - 중복 제거 하지 않는 것이 성능이 더 높음.

# %%
# df = df.drop_duplicates().reset_index(drop=True)

# %%
print(df.shape)
# Out:
# (152072, 29)

# %% [markdown]
# ## Preprocessing for Modeling

# %%
dataset = pd.get_dummies(df, columns = ['size_target', 'multicolor', 'Collabo_class'])

# %%
print(dataset.shape)
dataset.head()
# Out:
# (158192, 33)
#     size   price    date                            product  release_date  \
# 16   235  125000  738101  (W) Nike Dunk Low SE Primal Black        738101
# 17   250  119000  738101  (W) Nike Dunk Low SE Primal Black        738101
# 18   235  124000  738108  (W) Nike Dunk Low SE Primal Black        738101
# 19   255  149000  738112  (W) Nike Dunk Low SE Primal Black        738101
# 20   240  120000  738118  (W) Nike Dunk Low SE Primal Black        738101
#
#                       color  release_price brand   category  number  wish  \
# 16  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
# 17  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
# 18  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
# 19  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
# 20  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
#
#     review  transactions  review_log  wish_log size_type  color_count color1  \
# 16       4            30           1         5         W            3  BLACK
# 17       4            30           1         5         W            3  BLACK
# 18       4            30           1         5         W            3  BLACK
# 19       4            30           1         5         W            3  BLACK
# 20       4            30           1         5         W            3  BLACK
#
#          color2 color3 color4  Collabo Collabo_brand  after_day  \
# 16  MULTI-COLOR  BLACK           False           NaN          0
# 17  MULTI-COLOR  BLACK           False           NaN          0
# 18  MULTI-COLOR  BLACK           False           NaN          7
# 19  MULTI-COLOR  BLACK           False           NaN         11
# 20  MULTI-COLOR  BLACK           False           NaN         17
#
#     size_target_Female  size_target_Kids  size_target_Male  multicolor_False  \
# 16                   1                 0                 0                 0
# 17                   1                 0                 0                 0
# 18                   1                 0                 0                 0
# 19                   1                 0                 0                 0
# 20                   1                 0                 0                 0
#
#     multicolor_True  Collabo_class_Highend  Collabo_class_None  \
# 16                1                      0                   1
# 17                1                      0                   1
# 18                1                      0                   1
# 19                1                      0                   1
# 20                1                      0                   1
#
#     Collabo_class_Normal  Collabo_class_Preminum
# 16                     0                       0
# 17                     0                       0
# 18                     0                       0
# 19                     0                       0
# 20                     0                       0

# %%
dataset.loc[dataset['Collabo'] == True, 'Collabo'] = 1
dataset.loc[dataset['Collabo'] == False, 'Collabo'] = 0

# %%
pd.set_option('display.float_format','{:.2f}'.format)
corr = dataset.corr()['price'].sort_values(ascending=False)

# %%
corr
# Out:
# price                     1.00
# Collabo_class_Highend     0.66
# release_price             0.46
# Collabo_class_Preminum    0.45
# size_target_Male          0.35
# after_day                 0.29
# size                      0.28
# review_log                0.25
# review                    0.11
# multicolor_True           0.10
# wish_log                  0.05
# wish                      0.00
# transactions              0.00
# Collabo_class_Normal     -0.03
# color_count              -0.10
# multicolor_False         -0.10
# size_target_Kids         -0.19
# size_target_Female       -0.27
# date                     -0.28
# number                   -0.35
# release_date             -0.44
# Collabo_class_None       -0.60
# Name: price, dtype: float64

# %%
columns = corr[:11].index

# %%
y_label = dataset['price']
# x_data = dataset.drop(['price', 'date', 'product', 'release_date', 'color', 'brand', 'category', 'number', 'color_count', 'color1', 'color2', 'color3', 'color4', 'Collabo', 'Collabo_brand', 'multicolor_True', 'multicolor_False'], axis=1)
x_data = dataset[columns].drop(['price','review'], axis=1)

# %%
print(x_data.shape)
x_data.head()
# Out:
# (158192, 9)
#     Collabo_class_Highend  release_price  Collabo_class_Preminum  \
# 16                      0         129000                       0
# 17                      0         129000                       0
# 18                      0         129000                       0
# 19                      0         129000                       0
# 20                      0         129000                       0
#
#     size_target_Male  after_day  size  review_log  multicolor_True  wish_log
# 16                 0          0   235        1.39                1      4.53
# 17                 0          0   250        1.39                1      4.53
# 18                 0          7   235        1.39                1      4.53
# 19                 0         11   255        1.39                1      4.53
# 20                 0         17   240        1.39                1      4.53

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
x_columns = x_data.columns

# %%
x_data = scaler.fit_transform(x_data)

# %%
print(x_data.shape)
x_data
# Out:
# (158192, 9)
# array([[0.        , 0.41617122, 0.        , ..., 0.66733267, 1.        ,
#         0.15170719],
#        [0.        , 0.41617122, 0.        , ..., 0.66733267, 1.        ,
#         0.15170719],
#        [0.        , 0.41617122, 0.        , ..., 0.66733267, 1.        ,
#         0.15170719],
#        ...,
#        [0.        , 0.42508918, 0.        , ..., 0.69189882, 1.        ,
#         0.40780687],
#        [0.        , 0.42508918, 0.        , ..., 0.69189882, 1.        ,
#         0.40780687],
#        [0.        , 0.42508918, 0.        , ..., 0.69189882, 1.        ,
#         0.40780687]])

# %%
y_label = y_label.values.reshape(-1,1)

# %%
print(y_label.shape)
y_label
# Out:
# (158192, 1)
# array([[125000],
#        [119000],
#        [124000],
#        ...,
#        [269000],
#        [270000],
#        [210000]])

# %%
# x_data.to_csv('data/X_data.csv', index=False)
# y_label.to_csv('data/y_label.csv', index=False)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(x_data, y_label, train_size=0.8, random_state=45)

# %%
print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (110734, 9) (47458, 9) (110734, 1) (47458, 1)

# %%
X_train_val, X_test_val, y_train_val, y_test_val = train_test_split(X_train, y_train, train_size=0.7, random_state=45)

# %% [markdown]
# ## Model Selection
#
# - RandomForestRegressor : https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.RandomForestRegressor.html
# - XGBRegressor : https://xgboost.readthedocs.io/en/stable/python/python_api.html
# - LGBMRegressor
# - CatBoostRegressor : https://catboost.ai/en/docs/concepts/python-reference_train

# %% [markdown]
# ### 1. RandomForest

# %%
from sklearn.ensemble import RandomForestRegressor
# from xgboost import XGBRegressor
# from lightgbm import LGBMRegressor
# from catboost import CatBoostRegressor

# %%
rfr = RandomForestRegressor()
# xgbr = XGBRegressor()
# lgbmr = LGBMRegressor()
# catr = CatBoostRegressor()
# # xgbr = XGBRegressor(n_estimators=100, learning_rate=0.08, gamma=0, subsample=0.75,
# #                            colsample_bytree=1, max_depth=7)

# %%
rfr.fit(X_train_val, y_train_val)
# xgbr.fit(X_train,y_train)
# lgbmr.fit(X_train, y_train)
# catr.fit(X_train, y_train)
# Out:
# RandomForestRegressor()

# %%
from sklearn.metrics import mean_squared_error

rfr_pred = rfr.predict(X_test_val)
# xgbr_pred = xgbr.predict(X_test)
# lgbmr_pred = lgbmr.predict(X_test)
# catr_pred = catr.predict(X_test)

rfr_mse = mean_squared_error(y_test_val, rfr_pred)
# xgbr_mse = mean_squared_error(y_test, xgbr_pred)
# lgbmr_mse = mean_squared_error(y_test, lgbmr_pred)
# catr_mse = mean_squared_error(y_test, catr_pred)

rfr_rmse = np.sqrt(rfr_mse)
# xgbr_rmse = np.sqrt(xgbr_mse)
# lgbmr_rmse = np.sqrt(lgbmr_mse)
# catr_rmse = np.sqrt(catr_mse)

print(rfr_rmse)
# print(rfr_rmse, xgbr_rmse, lgbmr_rmse, catr_rmse)
# Out:
# 21883.895708897653

# %%
rfr_pred = rfr.predict(X_test)
rfr_mse = mean_squared_error(y_test, rfr_pred)
rfr_rmse = np.sqrt(rfr_mse)
print(rfr_rmse)
# Out:
# 21349.057169470372

# %%
from sklearn.metrics import r2_score
r2_score(y_test, rfr_pred)
# Out:
# 0.993887076143271

# %%
print(1 - (1-rfr.score(X_train, y_train))*(len(y_train)-1)/(len(y_train)-X_train.shape[1]-1))
# Out:
# 0.9968441158591359

# %%
X_train = pd.DataFrame(data = X_train, columns = x_columns)
y_train = pd.DataFrame(data = y_train, columns = ['price'])

# %%
index=rfr.feature_importances_.argsort()[::-1][0:-1]
index_imp=rfr.feature_importances_[index]
index_name=X_train.columns[index].tolist()
feature_importance=list(zip(index_name,index_imp))
feature_importance
# Out:
# [('Collabo_class_Highend', 0.43398807733088735),
#  ('Collabo_class_Preminum', 0.22939922641153962),
#  ('review_log', 0.1324248508376564),
#  ('release_price', 0.0647071670333954),
#  ('after_day', 0.05577575553866152),
#  ('wish_log', 0.04749870556515516),
#  ('size_target_Male', 0.02232827250391282),
#  ('size', 0.013563124235918572)]

# %%
# forest = RandomForestClassifier()
# forest.fit(X, y)

importances = rfr.feature_importances_
std = np.std([tree.feature_importances_ for tree in rfr.estimators_], axis=0)
indices = np.argsort(importances)[::-1]

# Print the feature ranking
print("Feature ranking:")

for f in range(X_train.shape[1]):
    print("{}. feature {} ({:.3f})".format(f + 1, X_train.columns[indices][f], importances[indices[f]]))

# Plot the impurity-based feature importances of the forest
plt.figure()
plt.title("Feature importances")
plt.bar(range(X_train.shape[1]), importances[indices],
        color="r", yerr=std[indices], align="center")
plt.xticks(range(X_train.shape[1]), X_train.columns[indices], rotation=45)
plt.xlim([-1, X_train.shape[1]])
plt.show()
# Out:
# Feature ranking:
# 1. feature Collabo_class_Highend (0.434)
# 2. feature Collabo_class_Preminum (0.229)
# 3. feature review (0.111)
# 4. feature release_price (0.059)
# 5. feature after_day (0.052)
# 6. feature wish (0.039)
# 7. feature transactions (0.039)
# 8. feature size_target_Male (0.022)
# 9. feature size (0.014)
# 10. feature Collabo_class_Normal (0.000)
# 11. feature Collabo_class_None (0.000)
# 12. feature size_target_Female (0.000)
# 13. feature size_target_Kids (0.000)

# %%
df.head(1)
# Out:
#    size   price    date                            product  release_date  \
# 0   235  125000  738101  (W) Nike Dunk Low SE Primal Black        738101
#
#                      color  release_price brand   category   number  wish  \
# 0  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk 41947.00 93.00
#
#    review  transactions size_target  color_count multicolor color1  \
# 0    4.00            30      Female            3       True  BLACK
#
#         color2 color3 color4  Collabo Collabo_brand  after_day Collabo_class
# 0  MULTI-COLOR  BLACK           False           NaN          0          None

# %% [markdown]
# ### 2. CatBoost

# %%
df.head(1)
# Out:
#    size   price    date                            product  release_date  \
# 0   235  125000  738101  (W) Nike Dunk Low SE Primal Black        738101
#
#                      color  release_price brand   category  number  wish  \
# 0  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk   41947    93
#
#    review  transactions size_target size_type  color_count multicolor color1  \
# 0       4            30      Female         W            3       True  BLACK
#
#         color2 color3 color4  Collabo Collabo_brand Collabo_class  after_day
# 0  MULTI-COLOR  BLACK           False           NaN          None          0

# %%
from catboost import CatBoostRegressor

cat_features = []
X_train = 
y_train

# %% [markdown]
# ### Featurn Selection
# - https://data-newbie.tistory.com/608

# %%
from BorutaShap import BorutaShap, load_data

X, y = load_data(data_type='regression')
X.head()
Feature_Selector = BorutaShap(importance_measure='shap',
                              classification=False)

Feature_Selector.fit(X=X, y=y, n_trials=100, random_state=0)
Feature_Selector.plot(X_size=12, figsize=(19,8),
                      y_scale='log', which_features='all',)

# %%
if self.importance_measure == 'shap':

self.explain()
vals = self.shap_values

if normalize:
vals = self.calculate_Zscore(vals)

X_feature_import = vals[:len(self.X.columns)]
Shadow_feature_import = vals[len(self.X_shadow.columns):]


elif self.importance_measure == 'gini':

feature_importances_ =  np.abs(self.model.feature_importances_)

if normalize:
feature_importances_ = self.calculate_Zscore(feature_importances_)

X_feature_import = feature_importances_[:len(self.X.columns)]
Shadow_feature_import = feature_importances_[len(self.X.columns):]

else:

raise ValueError('No Importance_measure was specified select one of (shap, gini)')

# %% [markdown]
# ## 하이퍼파라미터 튜닝

# %%
dataset['release_price'].mean()
# Out:
# 125574.04103873773

# %%
dataset['price'].median()
# Out:
# 280000.0

# %% [markdown]
# ### 1. Grid Search
# - https://www.kaggle.com/jayatou/xgbregressor-with-gridsearchcv

# %%
# RF
from sklearn.model_selection import GridSearchCV

params ={
    'n_estimators':[100],
    'max_depth':[6,8,10,12],
    'min_samples_leaf':[8,12,18],
    'min_samples_split':[8,16,20]
}

rf = RandomForestRegressor(random_state=0, n_jobs=-1)
grid_cv = GridSearchCV(rf, param_grid=params, cv=2, n_jobs=-1)
grid_cv.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=2, estimator=RandomForestRegressor(n_jobs=-1, random_state=0),
#              n_jobs=-1,
#              param_grid={'max_depth': [6, 8, 10, 12],
#                          'min_samples_leaf': [8, 12, 18],
#                          'min_samples_split': [8, 16, 20],
#                          'n_estimators': [100]})

# %%
pred = grid_cv.best_estimator_.predict(X_test)
mse = mean_squared_error(y_test, pred)
np.sqrt(mse)
# Out:
# 46991.65224387363

# %%
# XGB
from sklearn.model_selection import GridSearchCV

parameters = {'nthread':[4], #when use hyperthread, xgboost may become slower
              'objective':['reg:linear'],
              'learning_rate': [.03, 0.05, .07], #so called `eta` value
              'max_depth': [5, 6, 7],
              'min_child_weight': [4],
              'silent': [1],
              'subsample': [0.7],
              'colsample_bytree': [0.7],
              'n_estimators': [500]}

xgbr = XGBRegressor()
xgb_grid = GridSearchCV(xgbr,
                        parameters,
                        cv = 2,
                        n_jobs = 5,
                        verbose=True)

xgb_grid.fit(x_data, y_label)

print(xgb_grid.best_score_)
print(xgb_grid.best_params_)
# Out:
# Fitting 2 folds for each of 9 candidates, totalling 18 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1207-2b0c5d680ba8> in <module>
#      18                         verbose=True)
#      19
# ---> 20 xgb_grid.fit(x_data, y_label)
#      21
#      22 print(xgb_grid.best_score_)
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/sklearn/model_selection/_search.py in fit(self, X, y, groups, **fit_params)
#     839                 return results
#     840
# --> 841             self._run_search(evaluate_candidates)
#     842
#     843             # multimetric is determined here because in the case of a callable
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/sklearn/model_selection/_search.py in _run_search(self, evaluate_candidates)
#    1286     def _run_search(self, evaluate_candidates):
#    1287         """Search all candidates in param_grid"""
# -> 1288         evaluate_candidates(ParameterGrid(self.param_grid))
#    1289
#    1290
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/sklearn/model_selection/_search.py in evaluate_candidates(candidate_params, cv, more_results)
#     793                               n_splits, n_candidates, n_candidates * n_splits))
#     794
# --> 795                 out = parallel(delayed(_fit_and_score)(clone(base_estimator),
#     796                                                        X, y,
#     797                                                        train=train, test=test,
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/joblib/parallel.py in __call__(self, iterable)
#    1052
#    1053             with self._backend.retrieval_context():
# -> 1054                 self.retrieve()
#    1055             # Make sure that we get a last message telling us we are done
#    1056             elapsed_time = time.time() - self._start_time
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/joblib/parallel.py in retrieve(self)
#     931             try:
#     932                 if getattr(self._backend, 'supports_timeout', False):
# --> 933                     self._output.extend(job.get(timeout=self.timeout))
#     934                 else:
#     935                     self._output.extend(job.get())
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/joblib/_parallel_backends.py in wrap_future_result(future, timeout)
#     540         AsyncResults.get from multiprocessing."""
#     541         try:
# --> 542             return future.result(timeout=timeout)
#     543         except CfTimeoutError as e:
#     544             raise TimeoutError from e
#
# ~/opt/anaconda3/envs/test/lib/python3.9/concurrent/futures/_base.py in result(self, timeout)
#     438                     return self.__get_result()
#     439
# --> 440                 self._condition.wait(timeout)
#     441
#     442                 if self._state in [CANCELLED, CANCELLED_AND_NOTIFIED]:
#
# ~/opt/anaconda3/envs/test/lib/python3.9/threading.py in wait(self, timeout)
#     310         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     311             if timeout is None:
# --> 312                 waiter.acquire()
#     313                 gotit = True
#     314             else:
#
# KeyboardInterrupt:

# %%
r_sq = xgbr.score(X_train, y_train)
print(r_sq)
# Out:
# 0.9859814866931647

# %%
xgboost.plot_importance(xgbr)
# Out:
# <AxesSubplot:title={'center':'Feature importance'}, xlabel='F score', ylabel='Features'>

# %% [markdown]
# ### 2. Optuna 활용
# - 출처 : https://www.kaggle.com/hamzaghanmi/xgboost-hyperparameter-tuning-using-optuna
# - 매우 오래걸리네..

# %%
def objective(trial):
    criterion = trial.suggest_categorical('criterion', ['mse', 'mae'])
    bootstrap = trial.suggest_categorical('bootstrap',['True','False'])
    max_depth = trial.suggest_int('max_depth', 1, 10000)
    max_features = trial.suggest_categorical('max_features', ['auto', 'sqrt','log2'])
    max_leaf_nodes = trial.suggest_int('max_leaf_nodes', 1, 10000)
    n_estimators =  trial.suggest_int('n_estimators', 30, 1000)
    
    regr = RandomForestRegressor(bootstrap = bootstrap, criterion = criterion,
                                 max_depth = max_depth, max_features = max_features,
                                 max_leaf_nodes = max_leaf_nodes,n_estimators = n_estimators,n_jobs=2)
    
    
    #regr.fit(X_train, y_train)
    #y_pred = regr.predict(X_val)
    #return r2_score(y_val, y_pred)
    
    score = cross_val_score(regr, X_train, y_train, cv=5, scoring="r2")
    r2_mean = score.mean()

    return r2_mean

# %%
#Execute optuna and set hyperparameters
study = optuna.create_study(direction='maximize')
study.optimize(objective, n_trials=50)

#Create an instance with tuned hyperparameters
optimised_rf = RandomForestRegressor(bootstrap = study.best_params['bootstrap'], criterion = study.best_params['criterion'],
                                     max_depth = study.best_params['max_depth'], max_features = study.best_params['max_features'],
                                     max_leaf_nodes = study.best_params['max_leaf_nodes'],n_estimators = study.best_params['n_estimators'],
                                     n_jobs=2)
#learn
optimised_rf.fit(X_train ,y_train)

# %%
import optuna

import xgboost as xgb
from catboost import CatBoostRegressor
import numpy as np
import pandas as pd
from sklearn.model_selection import KFold
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
def objective(trial,data=x_data,target=y_label):
    
    train_x, test_x, train_y, test_y = train_test_split(data, target, test_size=0.15,random_state=42)
    param = {
#         'tree_method':'gpu_hist',  # this parameter means using the GPU when training our model to speedup the training process
        'lambda': trial.suggest_loguniform('lambda', 1e-3, 10.0),
        'alpha': trial.suggest_loguniform('alpha', 1e-3, 10.0),
        'colsample_bytree': trial.suggest_categorical('colsample_bytree', [0.3,0.4,0.5,0.6,0.7,0.8,0.9,1.0]),
        'subsample': trial.suggest_categorical('subsample', [0.4,0.5,0.6,0.7,0.8,1.0]),
        'learning_rate': trial.suggest_categorical('learning_rate', [0.008,0.009,0.01,0.012,0.014,0.016,0.018, 0.02]),
        'n_estimators': 4000,
        'max_depth': trial.suggest_categorical('max_depth', [5,7,9,11,13,15,17,20]),
        'random_state': trial.suggest_categorical('random_state', [24, 48,2020]),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 300),
    }
    model = xgb.XGBRegressor(**param)  
    
    model.fit(train_x,train_y,eval_set=[(test_x,test_y)],early_stopping_rounds=100,verbose=False)
    
    preds = model.predict(test_x)
    
    rmse = mean_squared_error(test_y, preds,squared=False)
    
    return rmse

# %%
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=50)
print('Number of finished trials:', len(study.trials))
print('Best trial:', study.best_trial.params)
# Out:
# [I 2022-01-05 13:37:31,321] A new study created in memory with name: no-name-d85c40ef-64fa-40b2-8fbe-d22405379406
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1019-a1dabc8f29ea> in <module>
#       1 study = optuna.create_study(direction='minimize')
# ----> 2 study.optimize(objective, n_trials=50)
#       3 print('Number of finished trials:', len(study.trials))
#       4 print('Best trial:', study.best_trial.params)
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/optuna/study/study.py in optimize(self, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#     398             )
#     399
# --> 400         _optimize(
#     401             study=self,
#     402             func=func,
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/optuna/study/_optimize.py in _optimize(study, func, n_trials, timeout, n_jobs, catch, callbacks, gc_after_trial, show_progress_bar)
#      64     try:
#      65         if n_jobs == 1:
# ---> 66             _optimize_sequential(
#      67                 study,
#      68                 func,
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/optuna/study/_optimize.py in _optimize_sequential(study, func, n_trials, timeout, catch, callbacks, gc_after_trial, reseed_sampler_rng, time_start, progress_bar)
#     161
#     162         try:
# --> 163             trial = _run_trial(study, func, catch)
#     164         except Exception:
#     165             raise
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/optuna/study/_optimize.py in _run_trial(study, func, catch)
#     211
#     212     try:
# --> 213         value_or_values = func(trial)
#     214     except exceptions.TrialPruned as e:
#     215         # TODO(mamu): Handle multi-objective cases.
#
# <ipython-input-1018-ee5c989e11c3> in objective(trial, data, target)
#      16     model = xgb.XGBRegressor(**param)
#      17
# ---> 18     model.fit(train_x,train_y,eval_set=[(test_x,test_y)],early_stopping_rounds=100,verbose=False)
#      19
#      20     preds = model.predict(test_x)
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/xgboost/core.py in inner_f(*args, **kwargs)
#     504         for k, arg in zip(sig.parameters, args):
#     505             kwargs[k] = arg
# --> 506         return f(**kwargs)
#     507
#     508     return inner_f
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/xgboost/sklearn.py in fit(self, X, y, sample_weight, base_margin, eval_set, eval_metric, early_stopping_rounds, verbose, xgb_model, sample_weight_eval_set, base_margin_eval_set, feature_weights, callbacks)
#     787
#     788         model, feval, params = self._configure_fit(xgb_model, eval_metric, params)
# --> 789         self._Booster = train(
#     790             params,
#     791             train_dmatrix,
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/xgboost/training.py in train(params, dtrain, num_boost_round, evals, obj, feval, maximize, early_stopping_rounds, evals_result, verbose_eval, xgb_model, callbacks)
#     186     Booster : a trained booster model
#     187     """
# --> 188     bst = _train_internal(params, dtrain,
#     189                           num_boost_round=num_boost_round,
#     190                           evals=evals,
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/xgboost/training.py in _train_internal(params, dtrain, num_boost_round, evals, obj, feval, xgb_model, callbacks, evals_result, maximize, verbose_eval, early_stopping_rounds)
#      79         if callbacks.before_iteration(bst, i, dtrain, evals):
#      80             break
# ---> 81         bst.update(dtrain, i, obj)
#      82         if callbacks.after_iteration(bst, i, dtrain, evals):
#      83             break
#
# ~/opt/anaconda3/envs/test/lib/python3.9/site-packages/xgboost/core.py in update(self, dtrain, iteration, fobj)
#    1678
#    1679         if fobj is None:
# -> 1680             _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1681                                                     ctypes.c_int(iteration),
#    1682                                                     dtrain.handle))
#
# KeyboardInterrupt:

# %%
study.trials_dataframe()

# %%
#plot_optimization_histor: shows the scores from all trials as well as the best score so far at each point.
optuna.visualization.plot_optimization_history(study)

# %%
#plot_parallel_coordinate: interactively visualizes the hyperparameters and scores
optuna.visualization.plot_parallel_coordinate(study)

# %%
'''plot_slice: shows the evolution of the search. You can see where in the hyperparameter space your search
went and which parts of the space were explored more.'''
optuna.visualization.plot_slice(study)

# %%
#plot_contour: plots parameter interactions on an interactive chart. You can choose which hyperparameters you would like to explore.
optuna.visualization.plot_contour(study, params=['alpha',
                            #'max_depth',
                            'lambda',
                            'subsample',
                            'learning_rate',
                            'subsample'])

# %%
#Visualize parameter importances.
optuna.visualization.plot_param_importances(study)

# %%
#Visualize empirical distribution function
optuna.visualization.plot_edf(study)

# %%
# direction : score 값을 최대 또는 최소로 하는 방향으로 지정 
study = optuna.create_study(direction='minimize',sampler=TPESampler())

# n_trials : 시도 횟수 (미 입력시 Key interrupt가 있을 때까지 무한 반복)
study.optimize(lambda trial : objectiveXGB(trial, X,  y, X_test), n_trials=50)
print('Best trial: score {},\nparams {}'.format(study.best_trial.value,study.best_trial.params))

# Console 출력 예)
# Best trial: score 0.6918131483269861,
# params {'n_estimators': 1988, 'max_depth': 15, 'min_child_weight': 171, 'gamma': 2, 'colsample_bytree': 0.7, 'lambda': 0.009025835256777458, 'alpha': 1.0684343216052703, 'subsample': 0.6}

# %%
# 하이퍼파라미터별 중요도를 확인할 수 있는 그래프
optuna.visualization.plot_param_importances(study)

# 하이퍼파라미터 최적화 과정을 확인
optuna.visualization.plot_optimization_history(study)

# %% [markdown]
# ### 3. Random Search

# %%
# Coarse
import numpy as np
from sklearn.ensemble import RandomForestRegressor

# scikit-learn 패키지의 model_selection 모듈에 있는 cross_val_predict 함수를 가지고 옵니다.
from sklearn.model_selection import cross_val_predict

# scikit-learn의 metrics 모듈에서 mean_squared_log_error라는 이름의 함수를 가져옵니다.
# 이 함수는 앞서 설명한 RMSLE에서 R(Root)를 제외한 나머지 부분을 계산해줍니다.
from sklearn.metrics import mean_squared_log_error

# n_estimators는 트리의 갯수입니다.
# 보통은 높을수록 좋지만, 그만큼 실행 속도가 오래 걸리기 때문에 이번에는 적당한 값을 주겠습니다. (300 개)
# 나머지 하이퍼패리미터가 전부 튜닝되면, 그 다음에는 n_estimators를 최대한 높이 주면 됩니다. (ex: 1,000 개)
n_estimators = 300

# 랜덤 서치를 반복할 횟수입니다.
# 보통 100번을 반복합니다.
num_epoch = 100

# hyperparameter 탐색 결과를 리스트로 저장합니다.
coarse_hyperparameters_list = []

# num_epoch 횟수만큼 랜덤 서치를 반복합니다. (loop)
for epoch in range(num_epoch):
    # 2에서 100 사이의 정수형(int) 값을 랜덤하게 생성하여 max_depth 변수에 할당합니다.
    max_depth = np.random.randint(low = 2, high = 100)

    # 0.1에서 1.0 사이의 실수형(float) 값을 랜덤하게 생성하여  max_features 변수에 할당합니다.
    max_features = np.random.uniform(low = 0.1, high = 1.0)

    # Random Forest를 생성합니다. 옵션은 다음과 같습니다.
    # 1) n_estimators. 트리의 갯수입니다.
    # 2) max_depth. 트리의 깊이입니다. 지정한 숫자만큼 트리가 깊게 가지를 뻗습니다.
    # 3) max_features. Feature Sampling입니다. 0.0 ~ 1.0 사이의 값을 넣으면, 트리를 생성할 때 전체 feature에서 지정한 비율만큼만 feature를 사용합니다.
    # 4) n_jobs. 병렬처리 여부입니다. -1을 대입하면 컴퓨터에 존재하는 모든 코어(Core, ex: 듀얼코어, 쿼드코어)를 전부 활용합니다.
    # 5) random_state. 랜덤포레스트의 결과가 랜덤하게 나오는 것을 고정하는 옵션입니다. 아무 숫자나 넣어주면 됩니다. (공학 용어에서 쓰이는 Seed Number와 동일한 개념입니다)
    model = RandomForestRegressor(n_estimators = n_estimators,
                                  max_depth = max_depth,
                                  max_features = max_features,
                                  n_jobs = -1,
                                  random_state = 37)

    # 주어진 모델(랜덤포레스트)를 활용하여 Cross Validation을 합니다.
    # Cross Validation을 할 때는 cross_val_predict라는 함수를 사용하며, 이 함수에는 다음의 옵션이 들어갑니다.
    # 1) model. 점수를 측정할 머신러닝 모델(현재는 Random Forest)이 들어갑니다.
    # 2) X_train. train 데이터의 feature 입니다.
    # 3) y_train. train 데이터의 label 입니다.
    # 4) cv. Cross Validation에서 데이터를 조각낼(split) 갯수입니다. 총 20조각을 내야하기 때문에 20을 대입합니다.
    # 단, 이 Cross Validation을 할 때는 count 컬럼 하나를 사용하는게 아니라,
    # count, casual, registered 컬럼 세 개를 따로 예측합니다.
    # 또한 count, casual, registered 세 개를 그냥 사용하지 않고, log + 1 연산을 한 결과를 사용합니다.
    y_predict_log_casual = cross_val_predict(model, X_train, y_train_log_casual, cv = 20)
    y_predict_log_registered = cross_val_predict(model, X_train, y_train_log_registered, cv = 20)
    y_predict_log_count = cross_val_predict(model, X_train, y_train_log_count, cv = 20)

    # 위 Cross Validation을 통해 얻은 예측값을, exp - 1 연산을 함으로서
    # 다시 원래 자전거 대여량으로 변환시킵니다.
    y_predict_casual = np.exp(y_predict_log_casual) - 1
    y_predict_registered = np.exp(y_predict_log_registered) - 1
    y_predict_count = np.exp(y_predict_log_count) - 1

    # 이 결과를 "기하평균"을 통해 하나로 합칩니다. (트렌드적인 면모, 비율같은 것이 중요할 때 사용)
    # 이렇게 하면 결과적으로 train 데이터의 자전거 대여량의 예측값이 나옵니다.
    # 이 예측값을 y_predict라는 변수에 할당합니다.
    y_predict = np.sqrt((y_predict_casual + y_predict_registered) * y_predict_count)

    # train 데이터의 label에 해당하는 y_train과, train 데이터의 label의 예측값인 y_predict를 활용하여
    # Mean Squared Logarithmic Error(MSLE)를 계산합니다.
    # 이후 여기에 numpy의 sqrt(square root)를 활용하여 루트 연산을 합니다.
    # 이 결과가 사실상 Root Mean Squared Logarithmic Error(RMSLE)가 됩니다.
    # 이를 score라는 이름의 변수에 할당합니다.
    score = mean_squared_log_error(y_train_count, y_predict)
    score = np.sqrt(score)
    
    # hyperparameter 탐색 결과를 딕셔너리화 합니다.
    hyperparameters = {
        'epoch': epoch,
        'score': score,
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'max_features': max_features,
    }

    # hyperparameter 탐색 결과를 리스트에 저장합니다.
    coarse_hyperparameters_list.append(hyperparameters)

    # hyperparameter 탐색 결과를 출력합니다.
    print(f"{epoch:2} n_estimators = {n_estimators}, max_depth = {max_depth:2}, max_features = {max_features:.6f}, Score = {score:.5f}")

# coarse_hyperparameters_list를 Pandas의 DataFrame으로 변환합니다.
coarse_hyperparameters_list = pd.DataFrame.from_dict(coarse_hyperparameters_list)

# 변환한 coarse_hyperparameters_list를 score가 낮은 순으로 정렬합니다.
# (RMSE는 score가 낮을 수록 더 정확도가 높다고 가정합니다)
coarse_hyperparameters_list = coarse_hyperparameters_list.sort_values(by="score")

# coarse_hyperparameters_list 변수에 할당된 데이터의 행렬 사이즈를 출력합니다.
# 출력은 (row, column) 으로 표시됩니다.
print(coarse_hyperparameters_list.shape)

# coarse_hyperparameters_list의 상위 10개를 출력합니다.
coarse_hyperparameters_list.head(10)

# %%
# Fine
# 파이썬의 선형대수 패키지인 Numpy를 가져옵니다.
# 이를 줄여서 np라는 축약어로 사용합니다.
import numpy as np

# scikit-learn 패키지의 ensemble 모듈에 있는 RandomForestRegressor를 가지고 옵니다.
from sklearn.ensemble import RandomForestRegressor

# scikit-learn 패키지의 model_selection 모듈에 있는 cross_val_predict 함수를 가지고 옵니다.
from sklearn.model_selection import cross_val_predict

# scikit-learn의 metrics 모듈에서 mean_squared_log_error라는 이름의 함수를 가져옵니다.
# 이 함수는 앞서 설명한 RMSLE에서 R(Root)를 제외한 나머지 부분을 계산해줍니다.
from sklearn.metrics import mean_squared_log_error

# n_estimators는 트리의 갯수입니다.
# 보통은 높을수록 좋지만, 그만큼 실행 속도가 오래 걸리기 때문에 이번에는 적당한 값을 주겠습니다. (300 개)
# 나머지 하이퍼패리미터가 전부 튜닝되면, 그 다음에는 n_estimators를 최대한 높이 주면 됩니다. (ex: 1,000 개)
n_estimators = 300

# 랜덤 서치를 반복할 횟수입니다.
# 보통 100번을 반복합니다.
num_epoch = 100

# hyperparameter 탐색 결과를 리스트로 저장합니다.
fine_hyperparameters_list = []

# num_epoch 횟수만큼 랜덤 서치를 반복합니다.
for epoch in range(num_epoch):
    # 40에서 100 사이의 정수형(int) 값을 랜덤하게 생성하여 max_depth 변수에 할당합니다.
    max_depth = np.random.randint(low = 40, high = 100)

    # 0.6에서 1.0 사이의 실수형(float) 값을 랜덤하게 생성하여  max_features 변수에 할당합니다.
    max_features = np.random.uniform(low = 0.8, high = 1.0)

    # Random Forest를 생성합니다. 옵션은 다음과 같습니다.
    # 1) n_estimators. 트리의 갯수입니다.
    # 2) max_depth. 트리의 깊이입니다. 지정한 숫자만큼 트리가 깊게 가지를 뻗습니다.
    # 3) max_features. Feature Sampling입니다. 0.0 ~ 1.0 사이의 값을 넣으면, 트리를 생성할 때 전체 feature에서 지정한 비율만큼만 feature를 사용합니다.
    # 4) n_jobs. 병렬처리 여부입니다. -1을 대입하면 컴퓨터에 존재하는 모든 코어(Core, ex: 듀얼코어, 쿼드코어)를 전부 활용합니다.
    # 5) random_state. 랜덤포레스트의 결과가 랜덤하게 나오는 것을 고정하는 옵션입니다. 아무 숫자나 넣어주면 됩니다. (공학 용어에서 쓰이는 Seed Number와 동일한 개념입니다)
    model = RandomForestRegressor(n_estimators = n_estimators,
                                  max_depth = max_depth,
                                  max_features = max_features,
                                  n_jobs = -1,
                                  random_state = 37)

    # 주어진 모델(랜덤포레스트)를 활용하여 Cross Validation을 합니다.
    # Cross Validation을 할 때는 cross_val_predict라는 함수를 사용하며, 이 함수에는 다음의 옵션이 들어갑니다.
    # 1) model. 점수를 측정할 머신러닝 모델(현재는 Random Forest)이 들어갑니다.
    # 2) X_train. train 데이터의 feature 입니다.
    # 3) y_train. train 데이터의 label 입니다.
    # 4) cv. Cross Validation에서 데이터를 조각낼(split) 갯수입니다. 총 20조각을 내야하기 때문에 20을 대입합니다.
    # 단, 이 Cross Validation을 할 때는 count 컬럼 하나를 사용하는게 아니라,
    # count, casual, registered 컬럼 세 개를 따로 예측합니다.
    # 또한 count, casual, registered 세 개를 그냥 사용하지 않고, log + 1 연산을 한 결과를 사용합니다.
    y_predict_log_casual = cross_val_predict(model, X_train, y_train_log_casual, cv = 20)
    y_predict_log_registered = cross_val_predict(model, X_train, y_train_log_registered, cv = 20)
    y_predict_log_count = cross_val_predict(model, X_train, y_train_log_count, cv = 20)

    # 위 Cross Validation을 통해 얻은 예측값을, exp - 1 연산을 함으로서
    # 다시 원래 자전거 대여량으로 변환시킵니다.
    y_predict_casual = np.exp(y_predict_log_casual) - 1
    y_predict_registered = np.exp(y_predict_log_registered) - 1
    y_predict_count = np.exp(y_predict_log_count) - 1

    # 이 결과를 기하평균을 통해 하나로 합칩니다.
    # 이렇게 하면 결과적으로 train 데이터의 자전거 대여량의 예측값이 나옵니다.
    # 이 예측값을 y_predict라는 변수에 할당합니다.
    y_predict = np.sqrt((y_predict_casual + y_predict_registered) * y_predict_count)
    
    # hyperparameter 탐색 결과를 딕셔너리화 합니다.
    hyperparameters = {
        'epoch': epoch,
        'score': score,
        'n_estimators': n_estimators,
        'max_depth': max_depth,
        'max_features': max_features,
    }

    # hyperparameter 탐색 결과를 리스트에 저장합니다.
    fine_hyperparameters_list.append(hyperparameters)

    # hyperparameter 탐색 결과를 출력합니다.
    print(f"{epoch:2} n_estimators = {n_estimators}, max_depth = {max_depth:2}, max_features = {max_features:.6f}, Score = {score:.5f}")

# fine_hyperparameters_list를 Pandas의 DataFrame으로 변환합니다.
fine_hyperparameters_list = pd.DataFrame.from_dict(fine_hyperparameters_list)

# 변환한 fine_hyperparameters_list를 score가 낮은 순으로 정렬합니다.
# (RMSE는 score가 낮을 수록 더 정확도가 높다고 가정합니다)
fine_hyperparameters_list = fine_hyperparameters_list.sort_values(by="score")

# fine_hyperparameters_list 변수에 할당된 데이터의 행렬 사이즈를 출력합니다.
# 출력은 (row, column) 으로 표시됩니다.
print(fine_hyperparameters_list.shape)

# fine_hyperparameters_list의 상위 10개를 출력합니다.
fine_hyperparameters_list.head(10)

# %%
# 가장 score가 낮게 나온(=좋은 정확도가 나온) 하이퍼패러미터를 가져옵니다.
# 이를 best_hyperparameters라는 이름의 변수에 저장합니다.
best_hyperparameters = fine_hyperparameters_list.iloc[0]

# best_hyperparameters에서 max_depth 하이퍼패러미터만 가져옵니다.
# 이를 best_max_depth라는 이름의 변수에 저장합니다.
best_max_depth = best_hyperparameters["max_depth"]

# best_hyperparameters에서 max_features 하이퍼패러미터만 가져옵니다.
# 이를 best_max_features라는 이름의 변수에 저장합니다.
best_max_features = best_hyperparameters["max_features"]

# best_max_depth와 best_max_features를 출력합니다.
print(f"max_depth(best) = {best_max_depth}, max_features(best) = {best_max_features:.6f}")

# %%
# scikit-learn 패키지의 ensemble 모듈에 있는 RandomForestRegressor를 가지고 옵니다.
from sklearn.ensemble import RandomForestRegressor

# 하이퍼패러미터 튜닝이 끝났으면, 이제 n_estimators를 가능한 높은 값을 주겠습니다.
best_n_estimators = 3000

# 주의: 혹시 하이퍼패러미터 튜닝을 하는데 시간이 너무 오래 걸린다면,
# 이를 대신해서 다음의 하이퍼패러미터를 사용해주세요. (아래 두 줄의 주석을 풀면 됩니다)
# best_max_depth = 97
# best_max_features = 0.897703
        
# RandomForestRegressor를 생성합니다. 실행할 때는 다음의 옵션이 들어갑니다.
# 1) n_estimators. 트리의 갯수입니다. 지정한 갯수만큼 트리를 생성합니다.
# 2) max_depth. 트리의 깊이입니다. 지정한 숫자만큼 트리가 깊게 가지를 뻗습니다.
# 3) max_features. Feature Sampling입니다. 0.0 ~ 1.0 사이의 값을 넣으면, 트리를 생성할 때 전체 feature에서 지정한 비율만큼만 feature를 사용합니다.
# 4) n_jobs. 병렬처리 여부입니다. -1을 대입하면 컴퓨터에 존재하는 모든 코어(Core, ex: 듀얼코어, 쿼드코어)를 전부 활용합니다.
# 5) random_state. 랜덤포레스트의 결과가 랜덤하게 나오는 것을 고정하는 옵션입니다. 아무 숫자나 넣어주면 됩니다. (공학 용어에서 쓰이는 Seed Number와 동일한 개념입니다)
model = RandomForestRegressor(n_estimators = best_n_estimators,
                              max_depth = best_max_depth,
                              max_features = best_max_features,
                              random_state = 37,
                              n_jobs = -1)
model
