# %%
import pandas as pd
import numpy as np

import warnings
warnings.filterwarnings(action='ignore')

# %%
df = pd.read_csv('data/nike_dunk_low(raw).csv')
df.head(3)
# Out:
#   size     price      date                            product release_date  \
# 0  245  125,000원  21/09/30  (W) Nike Dunk Low SE Primal Black     21/11/07
# 1  240  123,000원  21/09/30  (W) Nike Dunk Low SE Primal Black     21/11/07
# 2  245  129,000원  21/10/01  (W) Nike Dunk Low SE Primal Black     21/11/07
#
#                      color release_price
# 0  BLACK/MULTI-COLOR/BLACK      129,000원
# 1  BLACK/MULTI-COLOR/BLACK      129,000원
# 2  BLACK/MULTI-COLOR/BLACK      129,000원

# %%
df.value_counts()
# Out:
# size  price     date      product                                    release_date  color                 release_price
# 270   600,000원  21/08/12  Nike x Off-White Dunk Low The 50 - Lot 18  21/08/09      SAIL/NEUTRALGREY      219,000원           24
#       330,000원  21/01/23  Nike Dunk Low Retro Black                  21/01/14      WHITE/BLACK           119,000원           20
# 265   440,000원  21/08/18  Nike x Off-White Dunk Low The 50 - Lot 46  21/08/16      SAIL/NEUTRALGREY      219,000원           20
# 275   240,000원  21/08/17  Nike Dunk Low SE Seoul                     21/08/12      BLACK/WHITE-RED-BLUE  129,000원           19
# 270   430,000원  21/08/18  Nike x Off-White Dunk Low The 50 - Lot 46  21/08/16      SAIL/NEUTRALGREY      219,000원           19
#                                                                                                                             ..
# 250   415,000원  21/12/02  Nike Dunk Low Retro PRM Halloween          21/10/21      SAIL/STARFISH-BLACK   €120(약160,900원)     1
#                 21/12/01  Nike Dunk Low Retro PRM Halloween          21/10/21      SAIL/STARFISH-BLACK   €120(약160,900원)     1
#                 21/11/19  Nike Dunk Low Retro PRM Halloween          21/10/21      SAIL/STARFISH-BLACK   €120(약160,900원)     1
#                 21/03/26  Nike Dunk Low Retro Black                  21/01/14      WHITE/BLACK           119,000원            1
# 90    94,000원   21/12/23  (TD) Nike Dunk Low SP Ceramic              20/11/19      BLACK/CERAMIC-NORI    69,000원             1
# Length: 129555, dtype: int64

# %%
df.shape
# Out:
# (173732, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 173732 entries, 0 to 173731
# Data columns (total 7 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   size           173732 non-null  object
#  1   price          173732 non-null  object
#  2   date           173732 non-null  object
#  3   product        173732 non-null  object
#  4   release_date   173732 non-null  object
#  5   color          173732 non-null  object
#  6   release_price  173732 non-null  object
# dtypes: object(7)
# memory usage: 9.3+ MB

# %%
# null 값 보기 
tot = df.isnull().sum().sort_values(ascending=False)
pct = (df.isnull().sum()/df.isnull().count()).sort_values(ascending=False)
missing_data = pd.concat([tot, pct], axis=1, keys=['Total', 'Percent'])
missing_data
# Out:
#                Total  Percent
# size               0      0.0
# price              0      0.0
# date               0      0.0
# product            0      0.0
# release_date       0      0.0
# color              0      0.0
# release_price      0      0.0

# %% [markdown]
# ###  Preprocessing

# %%
# size 컬럼에서 사이즈만 추출  

def size (x) :
    return str(x)[:3]

df['size'] = df["size"].apply(size)

# %%
df['size'] = df['size'].apply(int)

# %%
# price 컬럼  " , " 과 " 원 " 제거 

import re

def extract_num (num_str) :
    if type(num_str) == str :
        num_str = re.sub('[^0-9]','',num_str)
    return num_str

df['price'] = df['price'].apply(extract_num)
df.head()
# Out:
#    size   price      date                            product release_date  \
# 0   245  125000  21/09/30  (W) Nike Dunk Low SE Primal Black     21/11/07
# 1   240  123000  21/09/30  (W) Nike Dunk Low SE Primal Black     21/11/07
# 2   245  129000  21/10/01  (W) Nike Dunk Low SE Primal Black     21/11/07
# 3   275  129000  21/10/04  (W) Nike Dunk Low SE Primal Black     21/11/07
# 4   240  132000  21/10/04  (W) Nike Dunk Low SE Primal Black     21/11/07
#
#                      color release_price
# 0  BLACK/MULTI-COLOR/BLACK      129,000원
# 1  BLACK/MULTI-COLOR/BLACK      129,000원
# 2  BLACK/MULTI-COLOR/BLACK      129,000원
# 3  BLACK/MULTI-COLOR/BLACK      129,000원
# 4  BLACK/MULTI-COLOR/BLACK      129,000원

# %%
df['price'] = df['price'].apply(int)

# %%
# "통화기호 , 한글제거 ""

def NotWon(x):
    if '약' in x:
        r = x.find('약')
        return x[r+1:-2]
    else:
        return x[:-1]

df['release_price'] = df['release_price'].apply(NotWon)

# %%
# 가격누락된 컬럼 값 추가 (재확인 필요)
df.loc[df['release_price'] == '', 'release_price']  = '115,000'

# %%
# 특수문자 제거 
df['release_price'] = df['release_price'].apply(extract_num)
df.head()
# Out:
#    size   price      date                            product release_date  \
# 0   245  125000  21/09/30  (W) Nike Dunk Low SE Primal Black     21/11/07
# 1   240  123000  21/09/30  (W) Nike Dunk Low SE Primal Black     21/11/07
# 2   245  129000  21/10/01  (W) Nike Dunk Low SE Primal Black     21/11/07
# 3   275  129000  21/10/04  (W) Nike Dunk Low SE Primal Black     21/11/07
# 4   240  132000  21/10/04  (W) Nike Dunk Low SE Primal Black     21/11/07
#
#                      color release_price
# 0  BLACK/MULTI-COLOR/BLACK        129000
# 1  BLACK/MULTI-COLOR/BLACK        129000
# 2  BLACK/MULTI-COLOR/BLACK        129000
# 3  BLACK/MULTI-COLOR/BLACK        129000
# 4  BLACK/MULTI-COLOR/BLACK        129000

# %%
df['release_price'] = df['release_price'].apply(int)

# %%
# date , release_date 컬럼 변경 

df['date'] = df["date"].str.replace('/','-')
df['release_date'] = df['release_date'].str.replace('/','-')

# %%
# yyyy -mm-dd 형식으로 변환 
df['date'] = pd.to_datetime(df['date'], format='%y-%m-%d')

# %%
#release_date 누락된 값 추가 
df.loc[df['release_date'] == '-', 'release_date']  = '21-07-22'

# %%
# yyyy -mm-dd 형식으로 변환 
df['release_date'] = pd.to_datetime(df['release_date'], format='%y-%m-%d')

# %%
df.head()
# Out:
#    size   price       date                            product release_date  \
# 0   245  125000 2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 1   240  123000 2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 2   245  129000 2021-10-01  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 3   275  129000 2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 4   240  132000 2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
#
#                      color  release_price
# 0  BLACK/MULTI-COLOR/BLACK         129000
# 1  BLACK/MULTI-COLOR/BLACK         129000
# 2  BLACK/MULTI-COLOR/BLACK         129000
# 3  BLACK/MULTI-COLOR/BLACK         129000
# 4  BLACK/MULTI-COLOR/BLACK         129000

# %%
# # 향후 모델링을 고려해 날짜 형식을 Unix 형식으로 변환 

# import datetime as dt

# df['date'] = df['date'].map(dt.datetime.toordinal)
# df['release_date'] = df['release_date'].map(dt.datetime.toordinal)

# %%
df.head()
# Out:
#    size   price       date                            product release_date  \
# 0   245  125000 2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 1   240  123000 2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 2   245  129000 2021-10-01  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 3   275  129000 2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 4   240  132000 2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
#
#                      color  release_price
# 0  BLACK/MULTI-COLOR/BLACK         129000
# 1  BLACK/MULTI-COLOR/BLACK         129000
# 2  BLACK/MULTI-COLOR/BLACK         129000
# 3  BLACK/MULTI-COLOR/BLACK         129000
# 4  BLACK/MULTI-COLOR/BLACK         129000

# %%
products = pd.read_csv('data/products/products_nike_dunk.csv')

# %%
products.drop('Unnamed: 0', axis=1, inplace=True)

# %%
print(products.shape)
products.head()
# Out:
# (360, 6)
#                                   product brand   category  number  wish  \
# 0               Nike Dunk Low Retro Black  Nike  Nike Dunk   28029  5.2만
# 1                 (W) Nike Dunk Low Black  Nike  Nike Dunk   28030  3.8만
# 2            Nike Dunk Low Retro Grey Fog  Nike  Nike Dunk   41193  1.6만
# 3                (GS) Nike Dunk Low Black  Nike  Nike Dunk   28229  1.7만
# 4  Nike Dunk High Retro Championship Navy  Nike  Nike Dunk   39628  1.6만
#
#   review
# 0  7,820
# 1  2,947
# 2     84
# 3  1,061
# 4    291

# %%
products['review'] = products['review'].apply(extract_num).apply(int)

# %%
float(products['wish'][0][:-1])
# Out:
# 5.2

# %%
def number_transform(x):
    if '만' in x:
        return float(x[:-1])*10000
    else:
        return x

# %%
products['wish'] = products['wish'].apply(number_transform)

# %%
products['wish'] = products['wish'].apply(extract_num).apply(int)

# %%
dataset = pd.merge(df, products, how='left', on='product')
print(df.shape)
dataset.head()
# Out:
# (173732, 7)
#    size   price       date                            product release_date  \
# 0   245  125000 2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 1   240  123000 2021-09-30  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 2   245  129000 2021-10-01  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 3   275  129000 2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
# 4   240  132000 2021-10-04  (W) Nike Dunk Low SE Primal Black   2021-11-07
#
#                      color  release_price brand   category   number  wish  \
# 0  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 1  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 2  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 3  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
# 4  BLACK/MULTI-COLOR/BLACK         129000  Nike  Nike Dunk  41947.0  93.0
#
#    review
# 0     4.0
# 1     4.0
# 2     4.0
# 3     4.0
# 4     4.0

# %%
transactions = dataset['product'].value_counts()

# %%
transactions = pd.DataFrame({'product':transactions.index , 'transactions':transactions.values})

# %%
dataset = pd.merge(dataset, transactions, how='left', on='product')

# %%
dataset
# Out:
#         size   price       date                             product  \
# 0        245  125000 2021-09-30   (W) Nike Dunk Low SE Primal Black
# 1        240  123000 2021-09-30   (W) Nike Dunk Low SE Primal Black
# 2        245  129000 2021-10-01   (W) Nike Dunk Low SE Primal Black
# 3        275  129000 2021-10-04   (W) Nike Dunk Low SE Primal Black
# 4        240  132000 2021-10-04   (W) Nike Dunk Low SE Primal Black
# ...      ...     ...        ...                                 ...
# 173977   260  231000 2021-07-15  Nike SB Dunk Low Pro Midnight Navy
# 173978   260  250000 2021-08-17  Nike SB Dunk Low Pro Midnight Navy
# 173979   245  280000 2021-09-26  Nike SB Dunk Low Pro Midnight Navy
# 173980   280  250000 2021-10-05  Nike SB Dunk Low Pro Midnight Navy
# 173981   270  390000 2021-10-08  Nike SB Dunk Low Pro Midnight Navy
#
#        release_date                            color  release_price brand  \
# 0        2021-11-07          BLACK/MULTI-COLOR/BLACK         129000  Nike
# 1        2021-11-07          BLACK/MULTI-COLOR/BLACK         129000  Nike
# 2        2021-11-07          BLACK/MULTI-COLOR/BLACK         129000  Nike
# 3        2021-11-07          BLACK/MULTI-COLOR/BLACK         129000  Nike
# 4        2021-11-07          BLACK/MULTI-COLOR/BLACK         129000  Nike
# ...             ...                              ...            ...   ...
# 173977   2020-11-17  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY         119000   NaN
# 173978   2020-11-17  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY         119000   NaN
# 173979   2020-11-17  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY         119000   NaN
# 173980   2020-11-17  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY         119000   NaN
# 173981   2020-11-17  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY         119000   NaN
#
#          category   number  wish  review  transactions
# 0       Nike Dunk  41947.0  93.0     4.0            30
# 1       Nike Dunk  41947.0  93.0     4.0            30
# 2       Nike Dunk  41947.0  93.0     4.0            30
# 3       Nike Dunk  41947.0  93.0     4.0            30
# 4       Nike Dunk  41947.0  93.0     4.0            30
# ...           ...      ...   ...     ...           ...
# 173977        NaN      NaN   NaN     NaN           132
# 173978        NaN      NaN   NaN     NaN           132
# 173979        NaN      NaN   NaN     NaN           132
# 173980        NaN      NaN   NaN     NaN           132
# 173981        NaN      NaN   NaN     NaN           132
#
# [173982 rows x 13 columns]

# %%
dataset['transactions'].value_counts()
# Out:
# 18150    18150
# 1450     13050
# 7758      7758
# 6700      6700
# 4450      4450
#          ...
# 18          18
# 14          14
# 1           14
# 2           12
# 5           10
# Name: transactions, Length: 174, dtype: int64

# %%
## 콜라보 떼어내기

# %%
# dataset['product'][99999]
# Out:
# 'Nike x Parra SB Dunk Low Pro Abstract Art'

# %%
# collabo = 'Nike x '
# r1 = dataset['product'][99999].find(string)
# r2 = dataset['product'][99999][r1+len(string):].find(' ')
# dataset['product'][99999][r1+len(string):r1+len(string)+r2]
# Out:
# 'Parra'

# %%
# dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145554 entries, 0 to 145553
# Data columns (total 11 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   size           145554 non-null  int64
#  1   price          145554 non-null  int64
#  2   date           145554 non-null  datetime64[ns]
#  3   product        145554 non-null  object
#  4   release_date   145554 non-null  datetime64[ns]
#  5   color          145554 non-null  object
#  6   release_price  145554 non-null  int64
#  7   number         145553 non-null  float64
#  8   wish           145553 non-null  float64
#  9   review         145553 non-null  float64
#  10  transactions   145554 non-null  int64
# dtypes: datetime64[ns](2), float64(3), int64(4), object(2)
# memory usage: 12.2+ MB

# %%
dataset = dataset.reset_index(drop=True)

# %%
set(dataset['product'])
# Out:
# {'(GS) Nike Dunk Low Black',
#  '(GS) Nike Dunk Low Bright Crimson Game Royal',
#  '(GS) Nike Dunk Low Championship Grey',
#  '(GS) Nike Dunk Low Light Bone Tropical Twist',
#  '(GS) Nike Dunk Low PRM Halloween',
#  '(GS) Nike Dunk Low Pink Foam',
#  '(GS) Nike Dunk Low Pink Velvet',
#  '(GS) Nike Dunk Low Retro Championship Red',
#  '(GS) Nike Dunk Low Retro Hyper Cobalt',
#  '(GS) Nike Dunk Low SE Free.99 Black',
#  '(GS) Nike Dunk Low SE Free.99 White',
#  '(GS) Nike Dunk Low SE Next Nature Sequoia Olive',
#  '(GS) Nike Dunk Low SE Sail Multi Camo',
#  '(GS) Nike Dunk Low Ueno Panda',
#  '(GS) Nike Dunk Low University Blue',
#  '(GS) Nike Dunk Low Varsity Maize',
#  '(GS) Nike Dunk Low White Bone Peach Aqua',
#  '(GS) Nike x NBA Dunk Low Chicago',
#  '(GS) Nike x NBA Dunk Low Nets',
#  '(PS) Nike Dunk Low Black',
#  '(PS) Nike Dunk Low Bright Crimson Game Royal',
#  '(PS) Nike Dunk Low Championship Grey',
#  '(PS) Nike Dunk Low Gypsy Rose',
#  '(PS) Nike Dunk Low Orange Pearl',
#  '(PS) Nike Dunk Low PRM Halloween',
#  '(PS) Nike Dunk Low Pink Foam',
#  '(PS) Nike Dunk Low UNLV',
#  '(PS) Nike Dunk Low University Blue',
#  '(PS) Nike Dunk Low Varsity Maize',
#  '(PS) Nike Dunk low Retro Hyper Cobalt',
#  '(PS) Nike x Medicom Toy SB Dunk Low BE@RBRICK',
#  '(PS) Nike x NBA Dunk Low Chicago',
#  '(PS) Nike x Social Status Dunk Low Free Lunch Chocolate Milk',
#  '(TD) Nike Dunk Low Brazil 2020',
#  '(TD) Nike Dunk Low Championship Grey',
#  '(TD) Nike Dunk Low Light Bone Tropical Twist',
#  '(TD) Nike Dunk Low Orange Pearl',
#  '(TD) Nike Dunk Low PRM Halloween',
#  '(TD) Nike Dunk Low Pink Foam',
#  '(TD) Nike Dunk Low SP Ceramic',
#  '(TD) Nike Dunk Low SP Samba 2020',
#  '(TD) Nike Dunk Low SP Veneer',
#  '(TD) Nike Dunk Low UNLV',
#  '(TD) Nike Dunk Low University Blue',
#  '(TD) Nike Dunk low Retro Hyper Cobalt',
#  '(TD) Nike SB Dunk Low Raygun Tie-Dye Black',
#  '(TD) Nike x NBA Dunk Low Chicago',
#  '(TD) Nike x Sean Cliver SB Dunk Low Holiday Special',
#  '(TD) Nike x Social Status Dunk Low Free Lunch Chocolate Milk',
#  '(TD) Nike x Social Status Dunk Low Free Lunch Strawberry Milk',
#  '(W) Nike Dunk Low Archeo Pink',
#  '(W) Nike Dunk Low Barely Green',
#  '(W) Nike Dunk Low Black',
#  '(W) Nike Dunk Low Bronze Eclipse',
#  '(W) Nike Dunk Low Coast',
#  '(W) Nike Dunk Low Disrupt Barely Rose',
#  '(W) Nike Dunk Low Disrupt Black Gum',
#  '(W) Nike Dunk Low Disrupt Black White',
#  '(W) Nike Dunk Low Disrupt Cactus Flower',
#  '(W) Nike Dunk Low Disrupt Carbon Green',
#  '(W) Nike Dunk Low Disrupt Coconut Milk',
#  '(W) Nike Dunk Low Disrupt Desert Sand',
#  '(W) Nike Dunk Low Disrupt Firecracker',
#  '(W) Nike Dunk Low Disrupt Gym Red',
#  '(W) Nike Dunk Low Disrupt Multi-Color',
#  '(W) Nike Dunk Low Disrupt Pale Ivory',
#  '(W) Nike Dunk Low Disrupt Photon Dust',
#  '(W) Nike Dunk Low Disrupt Platinum Violet',
#  '(W) Nike Dunk Low Disrupt Sea Glass',
#  '(W) Nike Dunk Low Disrupt Siren Red',
#  '(W) Nike Dunk Low Disrupt Summit White Ghost',
#  '(W) Nike Dunk Low Disrupt Supa',
#  '(W) Nike Dunk Low Disrupt University Red',
#  '(W) Nike Dunk Low Disrupt White Metallic Gold',
#  '(W) Nike Dunk Low Disrupt White Metallic Silver',
#  '(W) Nike Dunk Low Essential Black Paisley',
#  '(W) Nike Dunk Low Essential Blue Paisley',
#  '(W) Nike Dunk Low Golden Gals Metallic Silver',
#  '(W) Nike Dunk Low Green Glow',
#  '(W) Nike Dunk Low Green Strike',
#  '(W) Nike Dunk Low Laser Orange',
#  '(W) Nike Dunk Low Light Bone',
#  '(W) Nike Dunk Low Light Soft Pink',
#  '(W) Nike Dunk Low Midnight Navy',
#  '(W) Nike Dunk Low Next Nature Black',
#  '(W) Nike Dunk Low Next Nature Cream White',
#  '(W) Nike Dunk Low Next Nature Gym Red',
#  '(W) Nike Dunk Low Next Nature Pale Coral',
#  '(W) Nike Dunk Low Next Nature Sail',
#  '(W) Nike Dunk Low Orange Pearl',
#  '(W) Nike Dunk Low Pearl White',
#  '(W) Nike Dunk Low Photon Dust',
#  '(W) Nike Dunk Low Pink Oxford',
#  '(W) Nike Dunk Low Retro Firecracker',
#  '(W) Nike Dunk Low SE Candy',
#  '(W) Nike Dunk Low SE Primal Black',
#  '(W) Nike Dunk Low SE Primal White',
#  '(W) Nike Dunk Low Sunset Pulse',
#  '(W) Nike Dunk Low Triple White',
#  '(W) Nike Dunk Low University Gold',
#  '(W) Nike Dunk Low Venice',
#  '(W) Nike Dunk Low White Green',
#  '(W) Nike Dunk Low Yellow Strike',
#  '(W) Nike x Comme des Garcons Dunk Low Black',
#  'Nike Dunk Low Flyknit University Red Wolf Grey',
#  'Nike Dunk Low Flyknit White Wolf Grey',
#  'Nike Dunk Low NY vs NY',
#  'Nike Dunk Low Premium BHM SB 2015',
#  'Nike Dunk Low Premium Siempre Familia',
#  'Nike Dunk Low Pro Premium Medium Curry',
#  'Nike Dunk Low Retro Black',
#  'Nike Dunk Low Retro Championship Goldenrod',
#  'Nike Dunk Low Retro Championship Grey',
#  'Nike Dunk Low Retro Championship Red',
#  'Nike Dunk Low Retro Firecracker',
#  'Nike Dunk Low Retro Grey Fog',
#  'Nike Dunk Low Retro Hyper Cobalt',
#  'Nike Dunk Low Retro Medium Grey',
#  'Nike Dunk Low Retro Midas Gold',
#  'Nike Dunk Low Retro Next Nature Sequoia Olive',
#  'Nike Dunk Low Retro PRM Cheetah',
#  'Nike Dunk Low Retro PRM Cider',
#  'Nike Dunk Low Retro PRM Halloween',
#  'Nike Dunk Low Retro PRM Zebra',
#  'Nike Dunk Low Retro University Blue',
#  'Nike Dunk Low Retro Varsity Green',
#  'Nike Dunk Low Retro Varsity Maize',
#  'Nike Dunk Low Rooted In Peace',
#  'Nike Dunk Low SE Black Multi Camo',
#  'Nike Dunk Low SE Dusty Olive',
#  'Nike Dunk Low SE Free.99 Black',
#  'Nike Dunk Low SE Free.99 White',
#  'Nike Dunk Low SE Seoul',
#  'Nike Dunk Low SE Seoul (with Special Gift)',
#  'Nike Dunk Low SP Brazil 2020',
#  'Nike Dunk Low SP Ceramic',
#  'Nike Dunk Low SP City Market',
#  'Nike Dunk Low SP Community Garden',
#  'Nike Dunk Low SP Kentucky 2020',
#  'Nike Dunk Low SP Plum',
#  'Nike Dunk Low SP Retro Viotech 2019',
#  'Nike Dunk Low SP Samba 2020',
#  'Nike Dunk Low SP Syracuse 2020',
#  'Nike Dunk Low SP University Red',
#  'Nike Dunk Low SP Veneer',
#  'Nike Dunk Low Triple White',
#  'Nike Dunk SB Low De La Soul 2015',
#  'Nike Dunk SB Low Gulf of Mexico',
#  'Nike Dunk SB Low Orange Box',
#  'Nike Dunk SB Low Pink Box',
#  'Nike Dunk SB Low Sea Crystal',
#  'Nike SB Dunk Low Black Washed Coral',
#  'Nike SB Dunk Low Corduroy Dusty Peach',
#  'Nike SB Dunk Low Hackey Sack',
#  'Nike SB Dunk Low Infrared (Orange Label)',
#  'Nike SB Dunk Low Island Green Gum',
#  'Nike SB Dunk Low Laser Orange',
#  'Nike SB Dunk Low MIA Skate Shop',
#  'Nike SB Dunk Low Orange Label',
#  'Nike SB Dunk Low Premium SB Primitive 112',
#  'Nike SB Dunk Low Premium White Game Royal',
#  'Nike SB Dunk Low Pro Black Pine Green',
#  'Nike SB Dunk Low Pro Blue Chill',
#  'Nike SB Dunk Low Pro Blue Fury',
#  'Nike SB Dunk Low Pro Camcorder',
#  'Nike SB Dunk Low Pro Celadon',
#  'Nike SB Dunk Low Pro Chicago',
#  'Nike SB Dunk Low Pro Classic Green',
#  'Nike SB Dunk Low Pro Clear Jade',
#  'Nike SB Dunk Low Pro Dark Russet',
#  'Nike SB Dunk Low Pro Fog',
#  'Nike SB Dunk Low Pro Hennessy',
#  'Nike SB Dunk Low Pro ISO Orange Label White Navy',
#  'Nike SB Dunk Low Pro Laser Blue',
#  'Nike SB Dunk Low Pro Midnight Navy',
#  'Nike SB Dunk Low Pro Mystic Navy',
#  'Nike SB Dunk Low Pro Night of Mischief Halloween',
#  'Nike SB Dunk Low Pro Premium Barcelona',
#  'Nike SB Dunk Low Pro Premium Mummy',
#  'Nike SB Dunk Low Pro Red Plum',
#  'Nike SB Dunk Low Pro Shadow',
#  'Nike SB Dunk Low Pro Street Hawker',
#  'Nike SB Dunk Low Pro Trail',
#  'Nike SB Dunk Low Pro Wheat',
#  'Nike SB Dunk Low Pro Wheat and Purple',
#  'Nike SB Dunk Low Raygun Tie-Dye Black',
#  'Nike SB Dunk Low Raygun Tie-Dye White',
#  'Nike SB Dunk Low Rivals Pack (East)',
#  'Nike SB Dunk Low Safari',
#  'Nike SB Dunk Low Truck It',
#  'Nike SB Dunk Low What The Paul',
#  'Nike SB Dunk Low Wheat',
#  'Nike SB Zoom Dunk Low Pro Binary Blue',
#  'Nike SB Zoom Dunk Low Pro Circuit Orange',
#  'Nike SB Zoom Dunk Low Pro Reverse Shark',
#  'Nike SB Zoom Dunk Low Pro Skate Camo',
#  "Nike x Ben & Jerry's SB Dunk Low Chunky Dunky",
#  "Nike x Ben & Jerry's SB Dunk Low Chunky Dunky (Special Box)",
#  'Nike x Ben-G SB Dunk Low',
#  'Nike x Concepts SB Dunk Low Grail (Regular Box)',
#  'Nike x Concepts SB Dunk Low Green Lobster (Special Box)',
#  'Nike x Concepts SB Dunk Low Purple Lobster (Regular Box)',
#  'Nike x Diamond Supply Co. SB Dunk Low Black Diamond',
#  'Nike x Diamond Supply Co. SB Dunk Low Canary Diamond (Friends & Family)',
#  'Nike x Diamond Supply Co. SB Dunk Low White Diamond',
#  'Nike x Frame Skate SB Dunk Low Pro Habibi',
#  'Nike x Grateful Dead SB Dunk Low Green Bear',
#  'Nike x Grateful Dead SB Dunk Low Yellow Bear',
#  'Nike x Instant Skateboards SB Dunk Low Pro',
#  "Nike x Kasina Dunk Low 80's Bus",
#  'Nike x Kasina Dunk Low Road Sign - Kasina Exclusive',
#  'Nike x Medicom Toy SB Zoom Dunk Low Elite BE@RBRICK',
#  'Nike x NBA Dunk Low Retro EMB Chicago',
#  'Nike x NBA Dunk Low Retro EMB Knicks',
#  'Nike x NBA Dunk Low Retro EMB Nets',
#  'Nike x Off-White Dunk Low Pine Green',
#  'Nike x Off-White Dunk Low The 50 - Lot 1',
#  'Nike x Off-White Dunk Low The 50 - Lot 12',
#  'Nike x Off-White Dunk Low The 50 - Lot 13',
#  'Nike x Off-White Dunk Low The 50 - Lot 17',
#  'Nike x Off-White Dunk Low The 50 - Lot 18',
#  'Nike x Off-White Dunk Low The 50 - Lot 19',
#  'Nike x Off-White Dunk Low The 50 - Lot 2',
#  'Nike x Off-White Dunk Low The 50 - Lot 20',
#  'Nike x Off-White Dunk Low The 50 - Lot 21',
#  'Nike x Off-White Dunk Low The 50 - Lot 22',
#  'Nike x Off-White Dunk Low The 50 - Lot 24',
#  'Nike x Off-White Dunk Low The 50 - Lot 28',
#  'Nike x Off-White Dunk Low The 50 - Lot 29',
#  'Nike x Off-White Dunk Low The 50 - Lot 30',
#  'Nike x Off-White Dunk Low The 50 - Lot 31',
#  'Nike x Off-White Dunk Low The 50 - Lot 32',
#  'Nike x Off-White Dunk Low The 50 - Lot 33',
#  'Nike x Off-White Dunk Low The 50 - Lot 35',
#  'Nike x Off-White Dunk Low The 50 - Lot 36',
#  'Nike x Off-White Dunk Low The 50 - Lot 37',
#  'Nike x Off-White Dunk Low The 50 - Lot 38',
#  'Nike x Off-White Dunk Low The 50 - Lot 40',
#  'Nike x Off-White Dunk Low The 50 - Lot 43',
#  'Nike x Off-White Dunk Low The 50 - Lot 45',
#  'Nike x Off-White Dunk Low The 50 - Lot 46',
#  'Nike x Off-White Dunk Low The 50 - Lot 47',
#  'Nike x Off-White Dunk Low The 50 - Lot 48',
#  'Nike x Off-White Dunk Low The 50 - Lot 49',
#  'Nike x Off-White Dunk Low The 50 - Lot 50',
#  'Nike x Off-White Dunk Low University Gold Midnight Navy',
#  'Nike x Off-White Dunk Low University Red',
#  'Nike x Parra SB Dunk Low',
#  'Nike x Parra SB Dunk Low Pro Abstract Art',
#  'Nike x Quartersnacks SB Dunk Low PRM 2014',
#  'Nike x Quartersnacks SB Dunk Low Zebra Cake',
#  'Nike x S.P.O.T. x Lance Mountain Dunk SB Low Black',
#  'Nike x Sean Cliver SB Dunk Low Holiday Special (Special Box)',
#  'Nike x Soulland SB Dunk Low FRI.day Part 02',
#  'Nike x Staple SB Dunk Low Black Pigeon',
#  'Nike x Staple SB Dunk Low Panda Pigeon',
#  'Nike x Stingwater SB Dunk Low Magic Mushroom',
#  'Nike x StrangeLove SB Dunk Low Pink (Regular Box)',
#  'Nike x Supreme SB Dunk Low Barkroot Brown',
#  'Nike x Supreme SB Dunk Low Black',
#  'Nike x Supreme SB Dunk Low Jewel Swoosh Gold',
#  'Nike x Supreme SB Dunk Low Jewel Swoosh Red',
#  'Nike x Supreme SB Dunk Low Mean Green',
#  'Nike x Travis Scott SB Dunk Low',
#  'Nike x Travis Scott SB Dunk Low (Special Box)',
#  "Nike x Verdy Girls Don't Cry SB Dunk Low",
#  'Nike x Verdy SB Dunk Low Pro Wasted Youth (Regular Box)',
#  'Nike x Verdy SB Dunk Low Pro Wasted Youth (Special Box)'}

# %%
dataset['product'].value_counts().head(20)
# Out:
# Nike Dunk Low Retro Black                    18150
# Nike Dunk Low SE Seoul                        7758
# (W) Nike Dunk Low Black                       6700
# Nike Dunk Low Retro University Blue           4450
# (W) Nike Dunk Low Light Bone                  4400
# Nike x Kasina Dunk Low 80's Bus               4345
# (GS) Nike Dunk Low Black                      4100
# Nike Dunk Low Retro Varsity Green             4050
# Nike x Off-White Dunk Low The 50 - Lot 18     3800
# Nike Dunk Low Retro Medium Grey               3107
# Nike x Off-White Dunk Low The 50 - Lot 46     3100
# Nike Dunk Low Retro Championship Red          3000
# (PS) Nike Dunk Low Black                      2985
# Nike SB Dunk Low Pro Chicago                  2900
# (W) Nike Dunk Low Next Nature Pale Coral      2837
# (W) Nike Dunk Low Triple White                2767
# Nike Dunk Low Retro Varsity Maize             2750
# (W) Nike Dunk Low Next Nature Sail            2594
# Nike Dunk Low SP Community Garden             2161
# Nike Dunk Low Retro Grey Fog                  2072
# Name: product, dtype: int64

# %%
dataset.drop_duplicates()['product'].value_counts().head(20)
# Out:
# Nike Dunk Low Retro Black                              8290
# Nike Dunk Low SE Seoul                                 4480
# (W) Nike Dunk Low Black                                4120
# Nike x Kasina Dunk Low 80's Bus                        3710
# Nike Dunk Low Retro University Blue                    3140
# (GS) Nike Dunk Low Black                               2843
# (W) Nike Dunk Low Light Bone                           2799
# Nike SB Dunk Low Pro Chicago                           2789
# (PS) Nike Dunk Low Black                               2463
# Nike Dunk Low Retro Varsity Green                      2424
# Nike x Off-White Dunk Low The 50 - Lot 18              2377
# Nike Dunk Low Retro Medium Grey                        2293
# Nike Dunk Low Retro Championship Red                   2165
# (W) Nike Dunk Low Triple White                         1939
# Nike x Off-White Dunk Low The 50 - Lot 46              1792
# Nike x Kasina Dunk Low Road Sign - Kasina Exclusive    1773
# (W) Nike Dunk Low Next Nature Pale Coral               1753
# Nike Dunk Low Retro Varsity Maize                      1730
# (W) Nike Dunk Low Next Nature Sail                     1536
# Nike Dunk Low Retro Grey Fog                           1523
# Name: product, dtype: int64

# %%
# csv 파일로 저장 

dataset.to_csv('data/nike_dunk_low(pre).csv')
