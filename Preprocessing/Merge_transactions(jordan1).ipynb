# %%
import pandas as pd
import warnings
warnings.filterwarnings(action= "ignore")

# %%
import os  
os.getcwd() # 현재 경로 확인
# Out:
# '/Users/yoonsung/YS_project/Final_Project/ResaleShoes'

# %%
path =  'data/jordan1/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝이 .csv인 경우

# %%
df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + i)
    df = pd.concat([df,data], ignore_index  = True)

# %%
df
# Out:
#         Unnamed: 0 size     price      date  \
# 0                0  300  250,000원  21/06/08
# 1                1  285  239,000원  21/06/08
# 2                2  280  260,000원  21/06/08
# 3                3  270  250,000원  21/06/08
# 4                4  260  349,000원  21/06/09
# ...            ...  ...       ...       ...
# 324542          13  235  239,000원  21/12/20
# 324543          14  235  245,000원  21/12/24
# 324544          15  280  289,000원  21/12/26
# 324545          16  250  235,000원  21/12/26
# 324546          17  280  289,000원  22/01/01
#
#                                         product release_date  \
# 0       Jordan 1 Retro High OG Light Fusion Red     21/06/12
# 1       Jordan 1 Retro High OG Light Fusion Red     21/06/12
# 2       Jordan 1 Retro High OG Light Fusion Red     21/06/12
# 3       Jordan 1 Retro High OG Light Fusion Red     21/06/12
# 4       Jordan 1 Retro High OG Light Fusion Red     21/06/12
# ...                                         ...          ...
# 324542   (W) Jordan 1 Mid Anti Gravity Machines     21/07/20
# 324543   (W) Jordan 1 Mid Anti Gravity Machines     21/07/20
# 324544   (W) Jordan 1 Mid Anti Gravity Machines     21/07/20
# 324545   (W) Jordan 1 Mid Anti Gravity Machines     21/07/20
# 324546   (W) Jordan 1 Mid Anti Gravity Machines     21/07/20
#
#                                          color    release_price
# 0       LIGHTFUSIONRED/WHITE-LASERORANGE-BLACK         199,000원
# 1       LIGHTFUSIONRED/WHITE-LASERORANGE-BLACK         199,000원
# 2       LIGHTFUSIONRED/WHITE-LASERORANGE-BLACK         199,000원
# 3       LIGHTFUSIONRED/WHITE-LASERORANGE-BLACK         199,000원
# 4       LIGHTFUSIONRED/WHITE-LASERORANGE-BLACK         199,000원
# ...                                        ...              ...
# 324542            DARKPONY/SATURNGOLD-REDSTONE  $120(약143,500원)
# 324543            DARKPONY/SATURNGOLD-REDSTONE  $120(약143,500원)
# 324544            DARKPONY/SATURNGOLD-REDSTONE  $120(약143,500원)
# 324545            DARKPONY/SATURNGOLD-REDSTONE  $120(약143,500원)
# 324546            DARKPONY/SATURNGOLD-REDSTONE  $120(약143,500원)
#
# [324547 rows x 8 columns]

# %%
df = df.drop("Unnamed: 0" , axis = 1)

# %%
df
# Out:
#        size     price      date                                  product  \
# 0       300  250,000원  21/06/08  Jordan 1 Retro High OG Light Fusion Red
# 1       285  239,000원  21/06/08  Jordan 1 Retro High OG Light Fusion Red
# 2       280  260,000원  21/06/08  Jordan 1 Retro High OG Light Fusion Red
# 3       270  250,000원  21/06/08  Jordan 1 Retro High OG Light Fusion Red
# 4       260  349,000원  21/06/09  Jordan 1 Retro High OG Light Fusion Red
# ...     ...       ...       ...                                      ...
# 324542  235  239,000원  21/12/20   (W) Jordan 1 Mid Anti Gravity Machines
# 324543  235  245,000원  21/12/24   (W) Jordan 1 Mid Anti Gravity Machines
# 324544  280  289,000원  21/12/26   (W) Jordan 1 Mid Anti Gravity Machines
# 324545  250  235,000원  21/12/26   (W) Jordan 1 Mid Anti Gravity Machines
# 324546  280  289,000원  22/01/01   (W) Jordan 1 Mid Anti Gravity Machines
#
#        release_date                                   color    release_price
# 0          21/06/12  LIGHTFUSIONRED/WHITE-LASERORANGE-BLACK         199,000원
# 1          21/06/12  LIGHTFUSIONRED/WHITE-LASERORANGE-BLACK         199,000원
# 2          21/06/12  LIGHTFUSIONRED/WHITE-LASERORANGE-BLACK         199,000원
# 3          21/06/12  LIGHTFUSIONRED/WHITE-LASERORANGE-BLACK         199,000원
# 4          21/06/12  LIGHTFUSIONRED/WHITE-LASERORANGE-BLACK         199,000원
# ...             ...                                     ...              ...
# 324542     21/07/20            DARKPONY/SATURNGOLD-REDSTONE  $120(약143,500원)
# 324543     21/07/20            DARKPONY/SATURNGOLD-REDSTONE  $120(약143,500원)
# 324544     21/07/20            DARKPONY/SATURNGOLD-REDSTONE  $120(약143,500원)
# 324545     21/07/20            DARKPONY/SATURNGOLD-REDSTONE  $120(약143,500원)
# 324546     21/07/20            DARKPONY/SATURNGOLD-REDSTONE  $120(약143,500원)
#
# [324547 rows x 7 columns]

# %%
df.to_csv('data/jordan_1(raw).csv', index=False)
