# %%
import pandas as pd
import warnings
warnings.filterwarnings(action= "ignore")

# %%
import os  
os.getcwd() # 현재 경로 확인
# Out:
# '/Users/yoonsung/YS_project/Final_Project/ResaleShoes'

# %%
path =  'data/transactions_nike_air_force/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝이 .csv인 경우

# %%
df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + i)
    df = pd.concat([df,data], ignore_index  = True)

# %%
df
# Out:
#        Unnamed: 0       size     price      date  \
# 0               0        240  180,000원  20/10/25
# 1               1        235  120,000원  21/03/03
# 2               2        270  198,000원  21/08/08
# 3               0  235(4.5Y)  179,000원  21/05/22
# 4               1  245(6.5Y)  189,000원  21/05/23
# ...           ...        ...       ...       ...
# 88472         413        270  241,000원  22/01/07
# 88473         414        220  295,000원  22/01/07
# 88474         415        220  299,000원  22/01/07
# 88475         416        235  218,000원  22/01/07
# 88476         417        235  219,000원  22/01/08
#
#                                                  product release_date  \
# 0      (W) Nike Air Force 1 LXX Game Royal University...     20/10/17
# 1      (W) Nike Air Force 1 LXX Game Royal University...     20/10/17
# 2      (W) Nike Air Force 1 LXX Game Royal University...     20/10/17
# 3               (GS) Nike Air Force 1 LV8 Double Swoosh      21/01/27
# 4               (GS) Nike Air Force 1 LV8 Double Swoosh      21/01/27
# ...                                                  ...          ...
# 88472          (W) Nike Air Force 1 Fontanka Pearl White     21/10/18
# 88473          (W) Nike Air Force 1 Fontanka Pearl White     21/10/18
# 88474          (W) Nike Air Force 1 Fontanka Pearl White     21/10/18
# 88475          (W) Nike Air Force 1 Fontanka Pearl White     21/10/18
# 88476          (W) Nike Air Force 1 Fontanka Pearl White     21/10/18
#
#                                                 color    release_price
# 0                       WHITE/GAMEROYAL-UNIVERSITYRED  $110(약132,300원)
# 1                       WHITE/GAMEROYAL-UNIVERSITYRED  $110(약132,300원)
# 2                       WHITE/GAMEROYAL-UNIVERSITYRED  $110(약132,300원)
# 3                   WHITE/LIGHTARMORYBLUE/ARCTICPUNCH   $90(약108,300원)
# 4                   WHITE/LIGHTARMORYBLUE/ARCTICPUNCH   $90(약108,300원)
# ...                                               ...              ...
# 88472  PEARLWHITE/PEARLWHITE/UNIVERSITYRED/PEARLWHITE         149,000원
# 88473  PEARLWHITE/PEARLWHITE/UNIVERSITYRED/PEARLWHITE         149,000원
# 88474  PEARLWHITE/PEARLWHITE/UNIVERSITYRED/PEARLWHITE         149,000원
# 88475  PEARLWHITE/PEARLWHITE/UNIVERSITYRED/PEARLWHITE         149,000원
# 88476  PEARLWHITE/PEARLWHITE/UNIVERSITYRED/PEARLWHITE         149,000원
#
# [88477 rows x 8 columns]

# %%
df = df.drop("Unnamed: 0" , axis = 1)

# %%
df
# Out:
#             size     price      date  \
# 0            240  180,000원  20/10/25
# 1            235  120,000원  21/03/03
# 2            270  198,000원  21/08/08
# 3      235(4.5Y)  179,000원  21/05/22
# 4      245(6.5Y)  189,000원  21/05/23
# ...          ...       ...       ...
# 88472        270  241,000원  22/01/07
# 88473        220  295,000원  22/01/07
# 88474        220  299,000원  22/01/07
# 88475        235  218,000원  22/01/07
# 88476        235  219,000원  22/01/08
#
#                                                  product release_date  \
# 0      (W) Nike Air Force 1 LXX Game Royal University...     20/10/17
# 1      (W) Nike Air Force 1 LXX Game Royal University...     20/10/17
# 2      (W) Nike Air Force 1 LXX Game Royal University...     20/10/17
# 3               (GS) Nike Air Force 1 LV8 Double Swoosh      21/01/27
# 4               (GS) Nike Air Force 1 LV8 Double Swoosh      21/01/27
# ...                                                  ...          ...
# 88472          (W) Nike Air Force 1 Fontanka Pearl White     21/10/18
# 88473          (W) Nike Air Force 1 Fontanka Pearl White     21/10/18
# 88474          (W) Nike Air Force 1 Fontanka Pearl White     21/10/18
# 88475          (W) Nike Air Force 1 Fontanka Pearl White     21/10/18
# 88476          (W) Nike Air Force 1 Fontanka Pearl White     21/10/18
#
#                                                 color    release_price
# 0                       WHITE/GAMEROYAL-UNIVERSITYRED  $110(약132,300원)
# 1                       WHITE/GAMEROYAL-UNIVERSITYRED  $110(약132,300원)
# 2                       WHITE/GAMEROYAL-UNIVERSITYRED  $110(약132,300원)
# 3                   WHITE/LIGHTARMORYBLUE/ARCTICPUNCH   $90(약108,300원)
# 4                   WHITE/LIGHTARMORYBLUE/ARCTICPUNCH   $90(약108,300원)
# ...                                               ...              ...
# 88472  PEARLWHITE/PEARLWHITE/UNIVERSITYRED/PEARLWHITE         149,000원
# 88473  PEARLWHITE/PEARLWHITE/UNIVERSITYRED/PEARLWHITE         149,000원
# 88474  PEARLWHITE/PEARLWHITE/UNIVERSITYRED/PEARLWHITE         149,000원
# 88475  PEARLWHITE/PEARLWHITE/UNIVERSITYRED/PEARLWHITE         149,000원
# 88476  PEARLWHITE/PEARLWHITE/UNIVERSITYRED/PEARLWHITE         149,000원
#
# [88477 rows x 7 columns]

# %%
df.to_csv('data/nike_air_force(raw).csv', index=False)
