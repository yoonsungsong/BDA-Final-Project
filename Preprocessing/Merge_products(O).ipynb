# %%
import pandas as pd
import warnings
warnings.filterwarnings(action= "ignore")

# %%
nike_dunk = pd.read_csv('data/products/products_nike_dunk.csv', index_col='Unnamed: 0')
nike_air_force = pd.read_csv('data/products/products_nike_air_force.csv', index_col='Unnamed: 0')
jordan_1 = pd.read_csv('data/products/products_jordan_1.csv', index_col='Unnamed: 0')
adidas_yeezy = pd.read_csv('data/products/products_adidas_yeezy.csv', index_col='Unnamed: 0')
converse_chuck_70 = pd.read_csv('data/products/products_converse_chuck_70.csv', index_col='Unnamed: 0')
# Out:
#                                      product brand   category  number  wish  \
# 0                  Nike Dunk Low Retro Black  Nike  Nike Dunk   28029  5.2만
# 1                    (W) Nike Dunk Low Black  Nike  Nike Dunk   28030  3.8만
# 2               Nike Dunk Low Retro Grey Fog  Nike  Nike Dunk   41193  1.6만
# 3                   (GS) Nike Dunk Low Black  Nike  Nike Dunk   28229  1.7만
# 4     Nike Dunk High Retro Championship Navy  Nike  Nike Dunk   39628  1.6만
# ..                                       ...   ...        ...     ...   ...
# 355     Nike Dunk SB High Distressed Leather  Nike  Nike Dunk    5623    14
# 356       Nike Dunk High Premium SB Flamingo  Nike  Nike Dunk   29101    21
# 357  Nike Dunk High CMFT Premium Light Retro  Nike  Nike Dunk   26242    11
# 358  Nike Dunk High CMFT Premium Red October  Nike  Nike Dunk   23842   111
# 359      Nike Dunk SB Low Red Patent Leather  Nike  Nike Dunk    5224    78
#
#     review
# 0    7,820
# 1    2,947
# 2       84
# ...
