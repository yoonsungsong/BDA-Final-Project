# %%
import pandas as pd
import warnings
warnings.filterwarnings(action= "ignore")

# %%
import os  
os.getcwd() # 현재 경로 확인
# Out:
# '/Users/yoonsung/YS_project/Final_Project/ResaleShoes'

# %%
path =  'data/nike_dunk_low/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝이 .csv인 경우

# %%
df = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + i)
    df = pd.concat([df,data], ignore_index  = True)

# %%
df
# Out:
#         Unnamed: 0 size     price      date  \
# 0                0  245  125,000원  21/09/30
# 1                1  240  123,000원  21/09/30
# 2                2  245  129,000원  21/10/01
# 3                3  275  129,000원  21/10/04
# 4                4  240  132,000원  21/10/04
# ...            ...  ...       ...       ...
# 173727         127  260  231,000원  21/07/15
# 173728         128  260  250,000원  21/08/17
# 173729         129  245  280,000원  21/09/26
# 173730         130  280  250,000원  21/10/05
# 173731         131  270  390,000원  21/10/08
#
#                                    product release_date  \
# 0        (W) Nike Dunk Low SE Primal Black     21/11/07
# 1        (W) Nike Dunk Low SE Primal Black     21/11/07
# 2        (W) Nike Dunk Low SE Primal Black     21/11/07
# 3        (W) Nike Dunk Low SE Primal Black     21/11/07
# 4        (W) Nike Dunk Low SE Primal Black     21/11/07
# ...                                    ...          ...
# 173727  Nike SB Dunk Low Pro Midnight Navy     20/11/17
# 173728  Nike SB Dunk Low Pro Midnight Navy     20/11/17
# 173729  Nike SB Dunk Low Pro Midnight Navy     20/11/17
# 173730  Nike SB Dunk Low Pro Midnight Navy     20/11/17
# 173731  Nike SB Dunk Low Pro Midnight Navy     20/11/17
#
#                                   color release_price
# 0               BLACK/MULTI-COLOR/BLACK      129,000원
# 1               BLACK/MULTI-COLOR/BLACK      129,000원
# 2               BLACK/MULTI-COLOR/BLACK      129,000원
# 3               BLACK/MULTI-COLOR/BLACK      129,000원
# 4               BLACK/MULTI-COLOR/BLACK      129,000원
# ...                                 ...           ...
# 173727  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY      119,000원
# 173728  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY      119,000원
# 173729  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY      119,000원
# 173730  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY      119,000원
# 173731  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY      119,000원
#
# [173732 rows x 8 columns]

# %%
df = df.drop("Unnamed: 0" , axis = 1)

# %%
df
# Out:
#        size     price      date                             product  \
# 0       245  125,000원  21/09/30   (W) Nike Dunk Low SE Primal Black
# 1       240  123,000원  21/09/30   (W) Nike Dunk Low SE Primal Black
# 2       245  129,000원  21/10/01   (W) Nike Dunk Low SE Primal Black
# 3       275  129,000원  21/10/04   (W) Nike Dunk Low SE Primal Black
# 4       240  132,000원  21/10/04   (W) Nike Dunk Low SE Primal Black
# ...     ...       ...       ...                                 ...
# 173727  260  231,000원  21/07/15  Nike SB Dunk Low Pro Midnight Navy
# 173728  260  250,000원  21/08/17  Nike SB Dunk Low Pro Midnight Navy
# 173729  245  280,000원  21/09/26  Nike SB Dunk Low Pro Midnight Navy
# 173730  280  250,000원  21/10/05  Nike SB Dunk Low Pro Midnight Navy
# 173731  270  390,000원  21/10/08  Nike SB Dunk Low Pro Midnight Navy
#
#        release_date                            color release_price
# 0          21/11/07          BLACK/MULTI-COLOR/BLACK      129,000원
# 1          21/11/07          BLACK/MULTI-COLOR/BLACK      129,000원
# 2          21/11/07          BLACK/MULTI-COLOR/BLACK      129,000원
# 3          21/11/07          BLACK/MULTI-COLOR/BLACK      129,000원
# 4          21/11/07          BLACK/MULTI-COLOR/BLACK      129,000원
# ...             ...                              ...           ...
# 173727     20/11/17  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY      119,000원
# 173728     20/11/17  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY      119,000원
# 173729     20/11/17  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY      119,000원
# 173730     20/11/17  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY      119,000원
# 173731     20/11/17  MIDNIGHTNAVY/BLACK/MIDNIGHTNAVY      119,000원
#
# [173732 rows x 7 columns]

# %%
path =  'data/transactions_dunk_high/'
file_list = os.listdir(path)
file_list_py = [file for file in file_list if file.endswith('.csv')] ## 파일명 끝이 .csv인 경우

# %%
df2 = pd.DataFrame()
for i in file_list_py:
    data = pd.read_csv(path + i)
    df2 = pd.concat([df2,data], ignore_index  = True)

# %%
df2 = df2.drop("Unnamed: 0" , axis = 1)

# %%
df2
# Out:
#       size         price      date                              product  \
# 0      280      399,000원  21/12/14  Nike Dunk High Retro University Red
# 1      270      399,000원  21/12/26  Nike Dunk High Retro University Red
# 2      260      150,000원  21/08/15  (W) Nike Dunk High Up Varsity Maize
# 3      240      134,000원  21/08/18  (W) Nike Dunk High Up Varsity Maize
# 4      255      139,000원  21/08/27  (W) Nike Dunk High Up Varsity Maize
# ...    ...           ...       ...                                  ...
# 50205  240      238,000원  22/01/06   (W) Nike Dunk High Black and White
# 50206  235      223,000원  22/01/06   (W) Nike Dunk High Black and White
# 50207  255  260,000원빠른배송  22/01/06   (W) Nike Dunk High Black and White
# 50208  245      248,000원  22/01/07   (W) Nike Dunk High Black and White
# 50209  245  268,000원빠른배송  22/01/07   (W) Nike Dunk High Black and White
#
#       release_date                                    color    release_price
# 0         21/11/19                      WHITE/UNIVERSITYRED  $110(약132,300원)
# 1         21/11/19                      WHITE/UNIVERSITYRED  $110(약132,300원)
# 2         21/08/15  VARSITYMAIZE/MIDNIGHTNAVY-UNIVERSITYRED         139,000원
# 3         21/08/15  VARSITYMAIZE/MIDNIGHTNAVY-UNIVERSITYRED         139,000원
# 4         21/08/15  VARSITYMAIZE/MIDNIGHTNAVY-UNIVERSITYRED         139,000원
# ...            ...                                      ...              ...
# 50205     21/05/01                WHITE/BLACK-UNIVERSITYRED         129,000원
# 50206     21/05/01                WHITE/BLACK-UNIVERSITYRED         129,000원
# 50207     21/05/01                WHITE/BLACK-UNIVERSITYRED         129,000원
# 50208     21/05/01                WHITE/BLACK-UNIVERSITYRED         129,000원
# 50209     21/05/01                WHITE/BLACK-UNIVERSITYRED         129,000원
#
# [50210 rows x 7 columns]

# %%
data = pd.concat([df, df2]).reset_index(drop=True)

# %%
data
# Out:
#        size         price      date                             product  \
# 0       245      125,000원  21/09/30   (W) Nike Dunk Low SE Primal Black
# 1       240      123,000원  21/09/30   (W) Nike Dunk Low SE Primal Black
# 2       245      129,000원  21/10/01   (W) Nike Dunk Low SE Primal Black
# 3       275      129,000원  21/10/04   (W) Nike Dunk Low SE Primal Black
# 4       240      132,000원  21/10/04   (W) Nike Dunk Low SE Primal Black
# ...     ...           ...       ...                                 ...
# 223937  240      238,000원  22/01/06  (W) Nike Dunk High Black and White
# 223938  235      223,000원  22/01/06  (W) Nike Dunk High Black and White
# 223939  255  260,000원빠른배송  22/01/06  (W) Nike Dunk High Black and White
# 223940  245      248,000원  22/01/07  (W) Nike Dunk High Black and White
# 223941  245  268,000원빠른배송  22/01/07  (W) Nike Dunk High Black and White
#
#        release_date                      color release_price
# 0          21/11/07    BLACK/MULTI-COLOR/BLACK      129,000원
# 1          21/11/07    BLACK/MULTI-COLOR/BLACK      129,000원
# 2          21/11/07    BLACK/MULTI-COLOR/BLACK      129,000원
# 3          21/11/07    BLACK/MULTI-COLOR/BLACK      129,000원
# 4          21/11/07    BLACK/MULTI-COLOR/BLACK      129,000원
# ...             ...                        ...           ...
# 223937     21/05/01  WHITE/BLACK-UNIVERSITYRED      129,000원
# 223938     21/05/01  WHITE/BLACK-UNIVERSITYRED      129,000원
# 223939     21/05/01  WHITE/BLACK-UNIVERSITYRED      129,000원
# 223940     21/05/01  WHITE/BLACK-UNIVERSITYRED      129,000원
# 223941     21/05/01  WHITE/BLACK-UNIVERSITYRED      129,000원
#
# [223942 rows x 7 columns]

# %%
data.to_csv('data/nike_dunk(raw).csv', index=False)
